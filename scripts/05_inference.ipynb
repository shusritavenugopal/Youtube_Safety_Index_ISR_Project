# %%
# !pip install better-profanity
# Out:
# Requirement already satisfied: better-profanity in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.7.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import time
import random
import sys
import os
import torch
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
# Import necessary libraries
import nltk
from better_profanity import profanity  # Using better_profanity for profanity check
import textstat
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import joblib

# %% [markdown]
# ## Step 1: Load the Saved Model

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

# Specify the path to the saved model
model_folder = "/Users/shusritavenugopal/Documents/MSIS/FALL2024/InformationStorageAndRetrieval/video_classification_project/saved_BERT_pretrained_models/model_20241211_133348_v839069"

# Load the model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained(model_folder)
tokenizer = AutoTokenizer.from_pretrained(model_folder)

# %% [markdown]
# ## Step 2: Load the Sample for Inference

# %%
sample = "../data/raw/video_information_with_transcripts_network.xlsx"
sample_df = pd.read_excel(sample, engine='openpyxl')  # Existing file

# %% [markdown]
# ## Step 2.1: Delete Duplicates

# %%
# Check for duplicates
print("Number of duplicates:", sample_df.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
# Remove duplicates
sample_df = sample_df.drop_duplicates()

# Confirm duplicates are removed
print("Number of duplicates after cleaning:", sample_df.duplicated().sum())
# Out:
# Number of duplicates after cleaning: 0

# %%
sample_df.columns
# Out:
# Index(['Video ID', 'Title', 'Description', 'Published At', 'Channel Title',
#        'Tags', 'Category ID', 'Category Label', 'Default Audio Language',
#        'Transcript'],
#       dtype='object')

# %%
# Rename specific columns
sample_df = sample_df.rename(columns={
    "Video ID": "video_id",
    "Title": "title",
    "Description": "description",
    'Published At': "published_at",
    'Channel Title': "channel_title",
    'Tags': "tags",
    'Category ID': "category_id",
    'Category Label': "category_label",
    'Default Audio Language': "default_audio_language",
    'Transcript': "transcript"
})

print(sample_df.head())
# Out:
#       video_id                                              title  \
# 0  ju4KQT0wL0I                                      All The Stars
# 1  7YaqzpitBXw            What are MLPs (Multilayer Perceptrons)?
# 2  ZQbWWOzvyfo                                            Verizon
# 3  u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4  hCcwCv3G1FQ                                         St. Chroma
#
#                                          description          published_at  \
# 0  Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 1  Learn about watsonx: https://ibm.biz/BdvxRg\n\...  2022-07-11T12:00:07Z
# 2  Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3  Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 4  Provided to YouTube by Columbia\n\nSt. Chroma ...  2024-10-28T10:02:12Z
#
#                 channel_title  \
# 0      Kendrick Lamar - Topic
# 1              IBM Technology
# 2                     Verizon
# 3                     Jubilee
# 4  Tyler, The Creator - Topic
#
#                                                 tags  category_id  \
# 0  Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...           10
# 1  IBM, IBM Cloud, AI, Artificial Intelligence, M...           27
# 2                                                NaN           28
# 3  jubilee, jubilee media, jubilee project, middl...           24
# 4  Tyler, The Creator Daniel Caesar CHROMAKOPIA S...           10
#
#          category_label default_audio_language  \
# 0                 Music                    NaN
# 1             Education                  en-US
# 2  Science & Technology                  en-US
# 3         Entertainment                     en
# 4                 Music                    NaN
#
#                                           transcript
# 0                           Transcript not available
# 1  You've probably heard of AI that can do really...
# 2  [Music] my internet my rules introducing my ho...
# 3  if you see me you consider me obese I wouldn't...
# 4                           Transcript not available

# %% [markdown]
# ## Step 2.2: Construct the necessary column

# %%
# Concatenate relevant fields into a dictionary-like structure for analysis
def get_text_dict(row):
    return {
        "title": row.get("title", ""),
        "description": row.get("description", ""),
        "transcript": row.get("transcript", ""),
        "category_label": row.get("category_label", ""),
        "channel_title": row.get("channel_title", ""),
    }

# Create a dictionary from text fields for analysis
sample_df["text_dict"] = sample_df.apply(get_text_dict, axis=1)
# Concatenate all text fields into a single string, handling missing values
sample_df["combined_text"] = sample_df["text_dict"].apply(lambda d: " ".join(str(v) for v in d.values() if pd.notnull(v)))

sample_df.head(5)
# Out:
#       video_id                                              title  \
# 0  ju4KQT0wL0I                                      All The Stars
# 1  7YaqzpitBXw            What are MLPs (Multilayer Perceptrons)?
# 2  ZQbWWOzvyfo                                            Verizon
# 3  u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4  hCcwCv3G1FQ                                         St. Chroma
#
#                                          description          published_at  \
# 0  Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 1  Learn about watsonx: https://ibm.biz/BdvxRg\n\...  2022-07-11T12:00:07Z
# 2  Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3  Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 4  Provided to YouTube by Columbia\n\nSt. Chroma ...  2024-10-28T10:02:12Z
#
#                 channel_title  \
# 0      Kendrick Lamar - Topic
# 1              IBM Technology
# 2                     Verizon
# 3                     Jubilee
# 4  Tyler, The Creator - Topic
#
#                                                 tags  category_id  \
# 0  Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...           10
# 1  IBM, IBM Cloud, AI, Artificial Intelligence, M...           27
# 2                                                NaN           28
# 3  jubilee, jubilee media, jubilee project, middl...           24
# 4  Tyler, The Creator Daniel Caesar CHROMAKOPIA S...           10
#
#          category_label default_audio_language  \
# 0                 Music                    NaN
# 1             Education                  en-US
# 2  Science & Technology                  en-US
# 3         Entertainment                     en
# 4                 Music                    NaN
#
#                                           transcript  \
# 0                           Transcript not available
# 1  You've probably heard of AI that can do really...
# 2  [Music] my internet my rules introducing my ho...
# 3  if you see me you consider me obese I wouldn't...
# 4                           Transcript not available
#
#                                            text_dict  \
# 0  {'title': 'All The Stars', 'description': 'Pro...
# 1  {'title': 'What are MLPs (Multilayer Perceptro...
# 2  {'title': 'Verizon', 'description': 'Switch to...
# 3  {'title': 'Is Being Fat A Choice? Fit Women vs...
# 4  {'title': 'St. Chroma', 'description': 'Provid...
#
#                                        combined_text
# 0  All The Stars Provided to YouTube by Universal...
# 1  What are MLPs (Multilayer Perceptrons)? Learn ...
# 2  Verizon Switch to Fios Home Internet w/ no hid...
# 3  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4  St. Chroma Provided to YouTube by Columbia\n\n...

# %%
sample_df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_title',
#        'tags', 'category_id', 'category_label', 'default_audio_language',
#        'transcript', 'text_dict', 'combined_text'],
#       dtype='object')

# %% [markdown]
# ## Step 3: Preprocess the feature column (X)
# ### Text pre-processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# Initialize tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Function to preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    
    # Remove special characters, numbers, and punctuation
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stop words and lemmatize tokens
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    
    # Rejoin tokens into a single string
    return ' '.join(tokens)

# Apply preprocessing to all text in X
sample_df["combined_text"] = sample_df["combined_text"].apply(preprocess_text)

# Check a few samples after preprocessing
print(sample_df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shusritavenugopal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shusritavenugopal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shusritavenugopal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#       video_id                                              title  \
# 0  ju4KQT0wL0I                                      All The Stars
# 1  7YaqzpitBXw            What are MLPs (Multilayer Perceptrons)?
# 2  ZQbWWOzvyfo                                            Verizon
# 3  u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4  hCcwCv3G1FQ                                         St. Chroma
#
#                                          description          published_at  \
# 0  Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 1  Learn about watsonx: https://ibm.biz/BdvxRg\n\...  2022-07-11T12:00:07Z
# 2  Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3  Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 4  Provided to YouTube by Columbia\n\nSt. Chroma ...  2024-10-28T10:02:12Z
#
#                 channel_title  \
# 0      Kendrick Lamar - Topic
# 1              IBM Technology
# 2                     Verizon
# 3                     Jubilee
# 4  Tyler, The Creator - Topic
#
#                                                 tags  category_id  \
# 0  Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...           10
# 1  IBM, IBM Cloud, AI, Artificial Intelligence, M...           27
# 2                                                NaN           28
# 3  jubilee, jubilee media, jubilee project, middl...           24
# 4  Tyler, The Creator Daniel Caesar CHROMAKOPIA S...           10
#
#          category_label default_audio_language  \
# 0                 Music                    NaN
# 1             Education                  en-US
# 2  Science & Technology                  en-US
# 3         Entertainment                     en
# 4                 Music                    NaN
#
#                                           transcript  \
# 0                           Transcript not available
# 1  You've probably heard of AI that can do really...
# 2  [Music] my internet my rules introducing my ho...
# 3  if you see me you consider me obese I wouldn't...
# 4                           Transcript not available
#
#                                            text_dict  \
# 0  {'title': 'All The Stars', 'description': 'Pro...
# 1  {'title': 'What are MLPs (Multilayer Perceptro...
# 2  {'title': 'Verizon', 'description': 'Switch to...
# 3  {'title': 'Is Being Fat A Choice? Fit Women vs...
# 4  {'title': 'St. Chroma', 'description': 'Provid...
#
#                                        combined_text
# 0  star provided youtube universal music group st...
# 1  mlps multilayer perceptrons learn watsonx http...
# 2  verizon switch fios home internet w hidden fee...
# 3  fat choice fit woman v fat woman middle ground...
# 4  st chroma provided youtube columbia st chroma ...

# %% [markdown]
# ## BERT Tokenizer

# %%
# Load pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize the 'combined_text' column from your sample_df
def tokenize_texts(texts, tokenizer, max_length=512):
    return tokenizer(
        texts.tolist(),           # Convert to list for batch processing
        padding=True,             # Pad sequences to the max length
        truncation=True,          # Truncate longer texts
        max_length=max_length,   # Maximum length for tokenized input
        return_tensors="pt"      # Return as pytorch tensors
    )

# Tokenize the 'combined_text' column from sample_df
encoded_inputs = tokenize_texts(sample_df["combined_text"], tokenizer)

# %%
# Convert to PyTorch Dataset
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, tokenized_inputs):
        self.input_ids = tokenized_inputs['input_ids']
        self.attention_mask = tokenized_inputs['attention_mask']

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_mask[idx],
        }

# Prepare the dataset
predict_dataset = CustomDataset(encoded_inputs)

# %%
# Create DataLoader for batching
predict_dataloader = torch.utils.data.DataLoader(predict_dataset, batch_size=64)

# Make predictions without moving to a specific device
predictions = []
with torch.no_grad():
    for batch in predict_dataloader:
        # Get the input_ids and attention_mask from the batch
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']

        # Get model outputs
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        batch_predictions = torch.argmax(logits, dim=1)
        
        predictions.extend(batch_predictions.numpy())  # Collect predictions

# Add predictions to the DataFrame
sample_df["kids_safe_BERT"] = predictions

# Save the DataFrame with predictions to a new file
sample_df.to_excel("predicted_sample_df.xlsx", index=False)
print("Predictions saved to 'predicted_sample_df.xlsx'.")
# Out:
# Predictions saved to 'predicted_sample_df.xlsx'.

# %%
sample_df
# Out:
#          video_id                                              title  \
# 0     ju4KQT0wL0I                                      All The Stars
# 1     7YaqzpitBXw            What are MLPs (Multilayer Perceptrons)?
# 2     ZQbWWOzvyfo                                            Verizon
# 3     u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4     hCcwCv3G1FQ                                         St. Chroma
# ...           ...                                                ...
# 2033  UuYKUgPQbDE  Subway Surfers The Animated Series | Rewind | ...
# 2034  Labo4AdJS_c  Mr Bean Finds Ancient Gold | Mr Bean Animated ...
# 2035  5Kr886vhpcc  DELUSIONAL #animation #animationart #insideout...
# 2036  T_evwI929vU              The New Norm: AWFUL Anti-Woke Cartoon
# 2037  vffu6FG4YP4                                 LACKADAISY (Pilot)
#
#                                             description          published_at  \
# 0     Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 1     Learn about watsonx: https://ibm.biz/BdvxRg\n\...  2022-07-11T12:00:07Z
# 2     Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3     Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 4     Provided to YouTube by Columbia\n\nSt. Chroma ...  2024-10-28T10:02:12Z
# ...                                                 ...                   ...
# 2033  📱 Download Subway Surfers for FREE at: https:/...  2019-03-23T15:00:05Z
# 2034  Whilst digging for buried treasure, Mr Bean di...  2024-11-10T14:00:24Z
# 2035                                                NaN  2024-08-08T18:29:49Z
# 2036  Twitter just unveiled their brand new “South P...  2024-06-28T01:54:26Z
# 2037  Get Merch and Support Animation! -  https://La...  2023-03-29T18:00:07Z
#
#                    channel_title  \
# 0         Kendrick Lamar - Topic
# 1                 IBM Technology
# 2                        Verizon
# 3                        Jubilee
# 4     Tyler, The Creator - Topic
# ...                          ...
# 2033              Subway Surfers
# 2034               Mr Bean World
# 2035                 Silent Jack
# 2036                     LS Mark
# 2037                  Lackadaisy
#
#                                                    tags  category_id  \
# 0     Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...           10
# 1     IBM, IBM Cloud, AI, Artificial Intelligence, M...           27
# 2                                                   NaN           28
# 3     jubilee, jubilee media, jubilee project, middl...           24
# 4     Tyler, The Creator Daniel Caesar CHROMAKOPIA S...           10
# ...                                                 ...          ...
# 2033  subway surfers, subway surfers animated series...            1
# 2034  Mr. Bean Cartoon World, funny cartoon, bean ca...            1
# 2035                                                NaN           24
# 2036                                                NaN           24
# 2037                                                NaN            1
#
#             category_label default_audio_language  \
# 0                    Music                    NaN
# 1                Education                  en-US
# 2     Science & Technology                  en-US
# 3            Entertainment                     en
# 4                    Music                    NaN
# ...                    ...                    ...
# 2033      Film & Animation                  en-US
# 2034      Film & Animation                  en-GB
# 2035         Entertainment                    NaN
# 2036         Entertainment                  en-GB
# 2037      Film & Animation                     en
#
#                                              transcript  \
# 0                              Transcript not available
# 1     You've probably heard of AI that can do really...
# 2     [Music] my internet my rules introducing my ho...
# 3     if you see me you consider me obese I wouldn't...
# 4                              Transcript not available
# ...                                                 ...
# 2033                           Transcript not available
# 2034                           Transcript not available
# 2035                           Transcript not available
# 2036                           Transcript not available
# 2037                           Transcript not available
#
#                                               text_dict  \
# 0     {'title': 'All The Stars', 'description': 'Pro...
# 1     {'title': 'What are MLPs (Multilayer Perceptro...
# 2     {'title': 'Verizon', 'description': 'Switch to...
# 3     {'title': 'Is Being Fat A Choice? Fit Women vs...
# 4     {'title': 'St. Chroma', 'description': 'Provid...
# ...                                                 ...
# 2033  {'title': 'Subway Surfers The Animated Series ...
# 2034  {'title': 'Mr Bean Finds Ancient Gold | Mr Bea...
# 2035  {'title': 'DELUSIONAL #animation #animationart...
# 2036  {'title': 'The New Norm: AWFUL Anti-Woke Carto...
# 2037  {'title': 'LACKADAISY (Pilot)', 'description':...
#
#                                           combined_text  kids_safe_BERT
# 0     star provided youtube universal music group st...               0
# 1     mlps multilayer perceptrons learn watsonx http...               0
# 2     verizon switch fios home internet w hidden fee...               0
# 3     fat choice fit woman v fat woman middle ground...               0
# 4     st chroma provided youtube columbia st chroma ...               1
# ...                                                 ...             ...
# 2033  subway surfer animated series rewind jake down...               0
# 2034  mr bean find ancient gold mr bean animated ful...               1
# 2035  delusional animation animationart insideout in...               0
# 2036  new norm awful antiwoke cartoon twitter unveil...               0
# 2037  lackadaisy pilot get merch support animation h...               0
#
# [2038 rows x 13 columns]

# %%
# Sample function definitions

# Check for profanity using the better_profanity library
def check_profanity(text):
    return profanity.contains_profanity(text)

def check_themes(text):
    sensitive_keywords = [
        "violence", "drugs", "sex", "explicit", "alcohol", "bomb", "gun", "fuck", 
        "abuse", "die", "kill", "unalive", "poison", "damn", "ghost", "scary", 
        "horror", "blood", "dead", "intimacy", "suggestive", "couple", "controversial", 
        "hot", "injuries", "romantic", "vampire", "shit", "sexy", "battle", "girlfriend", 
        "boyfriend", "scene kiss", "intercourse", "creepy", "naked", 
        "murder", "assault", "war", "massacre", "brutality", "stabbing", "shooting", 
        "gore", "torture", "hostility", "crime", "cocaine", "heroin", "nicotine", 
        "vaping", "addiction", "overdose", "substance abuse", "pills", "intoxicated", 
        "nudity", "erotic", "pornography", "fetish", "sensual", "lust", "strip", 
        "adult", "escort", "provocative", "cleavage", "lingerie", "scream", 
        "haunted", "supernatural", "zombie", "demon", "devil", "satanic", "cursed", 
        "exorcism", "nightmare", "fear", "terror", "trauma", "bullying", "harassment", 
        "suicide", "self-harm", "torture", "exploitation", "manipulation", 
        "oppression", "bastard", "hell", "slut", "whore", "damnation", "crap", 
        "douche", "asshole", "piss", "racism", "sexism", "discrimination", 
        "genocide", "terrorism", "dictatorship", "oppression", "xenophobia", 
        "cult", "stunt", "choking", "prank", "fire", "explosion", "theft", 
        "crime", "arrest", "kidnapping", "hostage", "escape", "affair", "adultery", 
        "infidelity", "lustful", "intimate", "sensual", "crush", "love triangle", 
        "gambling", "casino", "money laundering", "trafficking", "cheating", 
        "virus", "hacking", "dark web"
    ]
    text_lower = text.lower()
    return any(keyword in text_lower for keyword in sensitive_keywords)

# Check readability of the text using Flesch-Kincaid readability test
def check_readability(text):
    score = textstat.flesch_kincaid_grade(text)
    return score <= 5  # Grade level 5 is typically appropriate for kids

# Check sentiment tone using Vader sentiment analysis
def check_tone(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(text)["compound"]
    return sentiment_score > -0.2  # Positive tone

# Check for cultural sensitivity by looking for offensive phrases
def check_cultural_sensitivity(text):
    offensive_phrases = ["racist", "stereotype", "offensive"]
    text_lower = text.lower()
    return any(phrase in text_lower for phrase in offensive_phrases)

# Analyze the transcript for all criteria
def analyze_transcript(text):
    analysis_results = {
        "profanity": check_profanity(text),
        "themes": check_themes(text),
        "readability": check_readability(text),
        "tone": check_tone(text),
        "cultural_sensitivity": check_cultural_sensitivity(text)
    }
    return analysis_results

# Concatenate relevant fields into a dictionary-like structure for analysis
def get_text_dict(row):
    return {
        "title": row.get("title", ""),
        "description": row.get("description", ""),
        "transcript": row.get("transcript", ""),
        "category_label": row.get("Category Label", ""),
        "channel_title": row.get("channel_title", ""),
    }

# Analyze if content is safe based on keywords in channel title or tags
def is_kids_safe(row):
    # Safely extract and lower-case the channel title and tags
    channel_title = str(row.get("channel_title", "")).lower()  # Convert to string if not already
    tags = str(row.get("tags", "")).lower()  # Convert to string if not already
    
    # Check if any safe keyword exists in the channel title or tags
    if any(keyword.lower() in channel_title for keyword in safe_channels):
        return True
    if any(keyword.lower() in tags for keyword in safe_tags):
        return True
    return False

safe_channels = [
        "kids", "Cartoon Network India", "SpongeBob SquarePants Official", "WB kids", 
        "Masha and The Bear", "Peppa Pig - Official Channel", "Shaun the Sheep Official", 
        "Disney XD", "CARTOON AKG", "cartoon", "Videogyan Shows - Educational Videos For Kids", 
        "Bluey - Official Channel", "Disney Jr.", "Disney", "Mr Bean World", "Cartoonito", 
        "ariki Anime", "anime", "Nick Jr", "nursery", "rhymes", "cocomelon", "Dodo Kids", "Chewy"
    ]
    
safe_tags = [
        "learning", "toddler", "kids", "babies", "preschool", "family friendly", 
        "anime", "cartoon", "animation", "art", "drawing", "cute", "children", 
        "tom and jerry", "spongebob", "Scooby-Doo!", "Tom and Jerry", "Looney Tunes", 
        "Bugs Bunny", "spider-man", "phineas and ferb", "baby"
    ]

# %%
# Function to apply analysis to each row, considering all fields and specific keyword checks
def apply_analysis(df):
     # Perform analysis on the combined text
    df["profanity"] = df["combined_text"].apply(check_profanity)
    df["themes"] = df["combined_text"].apply(check_themes)
    df["readability"] = df["combined_text"].apply(check_readability)
    df["tone"] = df["combined_text"].apply(check_tone)
    df["cultural_sensitivity"] = df["combined_text"].apply(check_cultural_sensitivity)
    df["kids_safe_content"] = df.apply(is_kids_safe, axis=1)

    return df

# Apply the analysis functions to the DataFrame
sample_df = apply_analysis(sample_df)

# %%
sample_df.head(10)
# Out:
#       video_id                                              title  \
# 0  ju4KQT0wL0I                                      All The Stars
# 1  7YaqzpitBXw            What are MLPs (Multilayer Perceptrons)?
# 2  ZQbWWOzvyfo                                            Verizon
# 3  u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 4  hCcwCv3G1FQ                                         St. Chroma
# 5  eMFuvGuDuBk                                          Be A Man.
# 6  Ynu1FqBr3C4  QTMO2968100H_Q3 24_TMO Highlights_iPhone 16 Pr...
# 7  T5niXqwAnME  Big Muscle Guy Scars RELEASED #health #muscles...
# 8  EBGJuw6-2jE       Top gear x Osama bin laden💀💀💀 #topgear #edit
# 9  mHZRFs-faX8              Cooking Curry During College Lecture!
#
#                                          description          published_at  \
# 0  Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 1  Learn about watsonx: https://ibm.biz/BdvxRg\n\...  2022-07-11T12:00:07Z
# 2  Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3  Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 4  Provided to YouTube by Columbia\n\nSt. Chroma ...  2024-10-28T10:02:12Z
# 5  #motivation #hopecore #\nEmbrace your masculin...  2024-04-30T17:33:59Z
# 6  Subscribe to the T-Mobile YouTube channel:\nht...  2024-09-24T23:34:47Z
# 7  Support the channel with a membership! \nMembe...  2024-06-14T13:30:15Z
# 8                                                NaN  2023-11-03T08:23:14Z
# 9  Love you guys thank you so much for the suppor...  2024-10-13T02:00:02Z
#
#                 channel_title  \
# 0      Kendrick Lamar - Topic
# 1              IBM Technology
# 2                     Verizon
# 3                     Jubilee
# 4  Tyler, The Creator - Topic
# 5            Audentes Monarch
# 6                    T-Mobile
# 7      Mondragon Chiropractic
# 8                      Droopl
# 9                      Fique
#
#                                                 tags  category_id  \
# 0  Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...           10
# 1  IBM, IBM Cloud, AI, Artificial Intelligence, M...           27
# 2                                                NaN           28
# 3  jubilee, jubilee media, jubilee project, middl...           24
# 4  Tyler, The Creator Daniel Caesar CHROMAKOPIA S...           10
# 5  Audentes Monarch, adrenaline, discipline, gym ...           22
# 6  tmobile, t-mobile, t mobile, internet, wireles...           28
# 7                            asmr, relax, satisfying           27
# 8                                                NaN           22
# 9  D'Aydrian Harding, Fred Beyer, Ash Alk, Zople,...           24
#
#          category_label default_audio_language  \
# 0                 Music                    NaN
# 1             Education                  en-US
# 2  Science & Technology                  en-US
# 3         Entertainment                     en
# 4                 Music                    NaN
# 5        People & Blogs                  en-US
# 6  Science & Technology                  en-US
# 7             Education                     en
# 8        People & Blogs                    NaN
# 9         Entertainment                    NaN
#
#                                           transcript  \
# 0                           Transcript not available
# 1  You've probably heard of AI that can do really...
# 2  [Music] my internet my rules introducing my ho...
# 3  if you see me you consider me obese I wouldn't...
# 4                           Transcript not available
# 5  you're a man you are a man stand up and be a m...
# 6  check out Mahomes top three plays of the day h...
# 7  I don't have to get rid of the muscle just the...
# 8  here we are the cameras poised and ready and h...
# 9  [Music] so last video I asked you guys to get ...
#
#                                            text_dict  \
# 0  {'title': 'All The Stars', 'description': 'Pro...
# 1  {'title': 'What are MLPs (Multilayer Perceptro...
# 2  {'title': 'Verizon', 'description': 'Switch to...
# 3  {'title': 'Is Being Fat A Choice? Fit Women vs...
# 4  {'title': 'St. Chroma', 'description': 'Provid...
# 5  {'title': 'Be A Man.', 'description': '#motiva...
# 6  {'title': 'QTMO2968100H_Q3 24_TMO Highlights_i...
# 7  {'title': 'Big Muscle Guy Scars RELEASED #heal...
# 8  {'title': 'Top gear x Osama bin laden💀💀💀 #topg...
# 9  {'title': 'Cooking Curry During College Lectur...
#
#                                        combined_text  kids_safe_BERT  \
# 0  star provided youtube universal music group st...               0
# 1  mlps multilayer perceptrons learn watsonx http...               0
# 2  verizon switch fios home internet w hidden fee...               0
# 3  fat choice fit woman v fat woman middle ground...               0
# 4  st chroma provided youtube columbia st chroma ...               1
# 5  man motivation hopecore embrace masculinity le...               0
# 6  qtmohq tmo highlightsiphone pro usfamilies sav...               0
# 7  big muscle guy scar released health muscle kno...               0
# 8  top gear x osama bin laden topgear edit camera...               0
# 9  cooking curry college lecture love guy thank m...               0
#
#    profanity  themes  readability   tone  cultural_sensitivity  \
# 0      False   False        False   True                 False
# 1      False    True        False   True                 False
# 2      False   False        False  False                 False
# 3       True    True        False   True                 False
# 4      False   False        False   True                 False
# 5       True    True        False   True                 False
# 6      False   False        False   True                 False
# 7      False    True        False   True                 False
# 8      False   False        False   True                 False
# 9       True    True        False   True                 False
#
#    kids_safe_content
# 0              False
# 1               True
# 2              False
# 3              False
# 4              False
# 5               True
# 6               True
# 7              False
# 8              False
# 9              False

# %%
# Drop rows where `kids_safe_BERT` == 1 or `kids_safe_content` == True
filtered_df = sample_df[~((sample_df["kids_safe_BERT"] == 1) | (sample_df["kids_safe_content"] == True))]

filtered_df.head()
# Out:
#       video_id                                              title  \
# 0  ju4KQT0wL0I                                      All The Stars
# 2  ZQbWWOzvyfo                                            Verizon
# 3  u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 7  T5niXqwAnME  Big Muscle Guy Scars RELEASED #health #muscles...
# 8  EBGJuw6-2jE       Top gear x Osama bin laden💀💀💀 #topgear #edit
#
#                                          description          published_at  \
# 0  Provided to YouTube by Universal Music Group\n...  2018-12-12T09:55:47Z
# 2  Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3  Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 7  Support the channel with a membership! \nMembe...  2024-06-14T13:30:15Z
# 8                                                NaN  2023-11-03T08:23:14Z
#
#             channel_title                                               tags  \
# 0  Kendrick Lamar - Topic  Kendrick Lamar, ケンドリックラマー, ケンドリック・ラマー, SZA, シザ...
# 2                 Verizon                                                NaN
# 3                 Jubilee  jubilee, jubilee media, jubilee project, middl...
# 7  Mondragon Chiropractic                            asmr, relax, satisfying
# 8                  Droopl                                                NaN
#
#    category_id        category_label default_audio_language  \
# 0           10                 Music                    NaN
# 2           28  Science & Technology                  en-US
# 3           24         Entertainment                     en
# 7           27             Education                     en
# 8           22        People & Blogs                    NaN
#
#                                           transcript  \
# 0                           Transcript not available
# 2  [Music] my internet my rules introducing my ho...
# 3  if you see me you consider me obese I wouldn't...
# 7  I don't have to get rid of the muscle just the...
# 8  here we are the cameras poised and ready and h...
#
#                                            text_dict  \
# 0  {'title': 'All The Stars', 'description': 'Pro...
# 2  {'title': 'Verizon', 'description': 'Switch to...
# 3  {'title': 'Is Being Fat A Choice? Fit Women vs...
# 7  {'title': 'Big Muscle Guy Scars RELEASED #heal...
# 8  {'title': 'Top gear x Osama bin laden💀💀💀 #topg...
#
#                                        combined_text  kids_safe_BERT  \
# 0  star provided youtube universal music group st...               0
# 2  verizon switch fios home internet w hidden fee...               0
# 3  fat choice fit woman v fat woman middle ground...               0
# 7  big muscle guy scar released health muscle kno...               0
# 8  top gear x osama bin laden topgear edit camera...               0
#
#    profanity  themes  readability   tone  cultural_sensitivity  \
# 0      False   False        False   True                 False
# 2      False   False        False  False                 False
# 3       True    True        False   True                 False
# 7      False    True        False   True                 False
# 8      False   False        False   True                 False
#
#    kids_safe_content
# 0              False
# 2              False
# 3              False
# 7              False
# 8              False

# %%
# Drop rows where all the specified conditions are met
filtered_df = filtered_df[~(
    (sample_df["profanity"] == False) &
    (sample_df["themes"] == False) &
    (sample_df["tone"] == True) &
    (sample_df["cultural_sensitivity"] == False)
)]
filtered_df.head()
# Out:
# /var/folders/3l/hp2znwrj0rv_rl95k6pf5lwc0000gn/T/ipykernel_20263/3030512086.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = filtered_df[~(
#        video_id                                              title  \
# 2   ZQbWWOzvyfo                                            Verizon
# 3   u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 7   T5niXqwAnME  Big Muscle Guy Scars RELEASED #health #muscles...
# 9   mHZRFs-faX8              Cooking Curry During College Lecture!
# 10  yeSbUxW2M-4                   clips that made Kai Cenat famous
#
#                                           description          published_at  \
# 2   Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3   Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 7   Support the channel with a membership! \nMembe...  2024-06-14T13:30:15Z
# 9   Love you guys thank you so much for the suppor...  2024-10-13T02:00:02Z
# 10  clips that made Kai Cenat famous\nFOLLOW ME ON...  2022-12-31T17:00:38Z
#
#              channel_title                                               tags  \
# 2                  Verizon                                                NaN
# 3                  Jubilee  jubilee, jubilee media, jubilee project, middl...
# 7   Mondragon Chiropractic                            asmr, relax, satisfying
# 9                   Fique   D'Aydrian Harding, Fred Beyer, Ash Alk, Zople,...
# 10          Kai Cenat Live  Kai Cenat, Kai Cenat Live, Kai Cenat Livestrea...
#
#     category_id        category_label default_audio_language  \
# 2            28  Science & Technology                  en-US
# 3            24         Entertainment                     en
# 7            27             Education                     en
# 9            24         Entertainment                    NaN
# 10           24         Entertainment                  en-US
#
#                                            transcript  \
# 2   [Music] my internet my rules introducing my ho...
# 3   if you see me you consider me obese I wouldn't...
# 7   I don't have to get rid of the muscle just the...
# 9   [Music] so last video I asked you guys to get ...
# 10  from 1 to 10 like how how like from 1 through ...
#
#                                             text_dict  \
# 2   {'title': 'Verizon', 'description': 'Switch to...
# 3   {'title': 'Is Being Fat A Choice? Fit Women vs...
# 7   {'title': 'Big Muscle Guy Scars RELEASED #heal...
# 9   {'title': 'Cooking Curry During College Lectur...
# 10  {'title': 'clips that made Kai Cenat famous', ...
#
#                                         combined_text  kids_safe_BERT  \
# 2   verizon switch fios home internet w hidden fee...               0
# 3   fat choice fit woman v fat woman middle ground...               0
# 7   big muscle guy scar released health muscle kno...               0
# 9   cooking curry college lecture love guy thank m...               0
# 10  clip made kai cenat famous clip made kai cenat...               0
#
#     profanity  themes  readability   tone  cultural_sensitivity  \
# 2       False   False        False  False                 False
# 3        True    True        False   True                 False
# 7       False    True        False   True                 False
# 9        True    True        False   True                 False
# 10       True    True        False   True                 False
#
#     kids_safe_content
# 2               False
# 3               False
# 7               False
# 9               False
# 10              False

# %%
from better_profanity import profanity
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textstat import textstat

# Initialize better-profanity
profanity.load_censor_words()

# Function to check profanity and return unique words
def check_profanity(text):
    profanity_words = list(set([word for word in text.split() if profanity.contains_profanity(word)]))
    return profanity_words if profanity_words else None

# Function to check themes and return unique identified themes
def check_themes(text):
    sensitive_keywords = [
        "violence", "drugs", "sex", "explicit", "alcohol", "bomb", "gun", "fuck", 
        "abuse", "die", "kill", "unalive", "poison", "damn", "ghost", "scary", 
        "horror", "blood", "dead", "intimacy", "suggestive", "couple", "controversial", 
        "hot", "injuries", "romantic", "vampire", "shit", "sexy", "battle", "girlfriend", 
        "boyfriend", "scene kiss", "intercourse", "creepy", "naked", 
        "murder", "assault", "war", "massacre", "brutality", "stabbing", "shooting", 
        "gore", "torture", "hostility", "crime", "cocaine", "heroin", "nicotine", 
        "vaping", "addiction", "overdose", "substance abuse", "pills", "intoxicated", 
        "nudity", "erotic", "pornography", "fetish", "sensual", "lust", "strip", 
        "adult", "escort", "provocative", "cleavage", "lingerie", "scream", 
        "haunted", "supernatural", "zombie", "demon", "devil", "satanic", "cursed", 
        "exorcism", "nightmare", "fear", "terror", "trauma", "bullying", "harassment", 
        "suicide", "self-harm", "torture", "exploitation", "manipulation", 
        "oppression", "bastard", "hell", "slut", "whore", "damnation", "crap", 
        "douche", "asshole", "piss", "racism", "sexism", "discrimination", 
        "genocide", "terrorism", "dictatorship", "oppression", "xenophobia", 
        "cult", "stunt", "choking", "prank", "fire", "explosion", "theft", 
        "crime", "arrest", "kidnapping", "hostage", "escape", "affair", "adultery", 
        "infidelity", "lustful", "intimate", "sensual", "crush", "love triangle", 
        "gambling", "casino", "money laundering", "trafficking", "cheating", 
        "virus", "hacking", "dark web"
    ]
    text_lower = text.lower()
    identified_themes = list(set([keyword for keyword in sensitive_keywords if keyword in text_lower]))
    return identified_themes if identified_themes else None

# Function to check sentiment tone
def check_tone(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment_score = analyzer.polarity_scores(text)["compound"]
    return sentiment_score

# Function to check cultural sensitivity
def check_cultural_sensitivity(text):
    offensive_phrases = ["racist", "stereotype", "offensive"]
    text_lower = text.lower()
    identified_offensive_phrases = list(set([phrase for phrase in offensive_phrases if phrase in text_lower]))
    return bool(identified_offensive_phrases), identified_offensive_phrases

# Function to apply analysis to each row, considering all fields and specific keyword checks
def apply_analysis(df):
    # Create a dictionary from text fields for analysis
    df["profanity_words"], df["themes_identified"], df["tone_score"], df["contains_cultural_sensitivity"], df["cultural_sensitivity_identified"] = zip(
        *df["combined_text"].apply(lambda x: (
            check_profanity(x), 
            check_themes(x), 
            check_tone(x), 
            *check_cultural_sensitivity(x)
        ))
    )
    return df

# Apply the analysis functions to the DataFrame
filtered_df = apply_analysis(filtered_df)

# %%
filtered_df
# Out:
#          video_id                                              title  \
# 2     ZQbWWOzvyfo                                            Verizon
# 3     u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 7     T5niXqwAnME  Big Muscle Guy Scars RELEASED #health #muscles...
# 9     mHZRFs-faX8              Cooking Curry During College Lecture!
# 10    yeSbUxW2M-4                   clips that made Kai Cenat famous
# ...           ...                                                ...
# 2013  qEP2Uujafr4  Beetlejuice: The Forgotten Animated Series #sh...
# 2022  _jo6CEr-LKQ  Pre-Ranking Marvel Animation TV Shows Based On...
# 2026  -WsZ2fUXbZg                           The Night (Fan Animated)
# 2036  T_evwI929vU              The New Norm: AWFUL Anti-Woke Cartoon
# 2037  vffu6FG4YP4                                 LACKADAISY (Pilot)
#
#                                             description          published_at  \
# 2     Switch to Fios Home Internet w/ no hidden fees...  2024-07-03T02:03:05Z
# 3     Got injured in an accident? You could be one  ...  2024-10-16T16:01:03Z
# 7     Support the channel with a membership! \nMembe...  2024-06-14T13:30:15Z
# 9     Love you guys thank you so much for the suppor...  2024-10-13T02:00:02Z
# 10    clips that made Kai Cenat famous\nFOLLOW ME ON...  2022-12-31T17:00:38Z
# ...                                                 ...                   ...
# 2013  #Beetlejuice #JennaOrtega #MichaelKeaton #timb...  2024-09-04T08:15:05Z
# 2022  In this video, we pre-rank the upcoming Marvel...  2024-06-30T13:42:54Z
# 2026  Watch the rest of the series: https://www.yout...  2016-07-15T15:19:09Z
# 2036  Twitter just unveiled their brand new “South P...  2024-06-28T01:54:26Z
# 2037  Get Merch and Support Animation! -  https://La...  2023-03-29T18:00:07Z
#
#                channel_title  \
# 2                    Verizon
# 3                    Jubilee
# 7     Mondragon Chiropractic
# 9                     Fique
# 10            Kai Cenat Live
# ...                      ...
# 2013           Barry_Is_H3r3
# 2022              DoomBlazer
# 2026             Daria Cohen
# 2036                 LS Mark
# 2037              Lackadaisy
#
#                                                    tags  category_id  \
# 2                                                   NaN           28
# 3     jubilee, jubilee media, jubilee project, middl...           24
# 7                               asmr, relax, satisfying           27
# 9     D'Aydrian Harding, Fred Beyer, Ash Alk, Zople,...           24
# 10    Kai Cenat, Kai Cenat Live, Kai Cenat Livestrea...           24
# ...                                                 ...          ...
# 2013                                                NaN           24
# 2022                                                NaN           24
# 2026  voltaire vampires the night twilight goth, hal...            1
# 2036                                                NaN           24
# 2037                                                NaN            1
#
#             category_label default_audio_language  \
# 2     Science & Technology                  en-US
# 3            Entertainment                     en
# 7                Education                     en
# 9            Entertainment                    NaN
# 10           Entertainment                  en-US
# ...                    ...                    ...
# 2013         Entertainment                  en-US
# 2022         Entertainment                  en-US
# 2026      Film & Animation                     en
# 2036         Entertainment                  en-GB
# 2037      Film & Animation                     en
#
#                                              transcript  ... themes  \
# 2     [Music] my internet my rules introducing my ho...  ...  False
# 3     if you see me you consider me obese I wouldn't...  ...   True
# 7     I don't have to get rid of the muscle just the...  ...   True
# 9     [Music] so last video I asked you guys to get ...  ...   True
# 10    from 1 to 10 like how how like from 1 through ...  ...   True
# ...                                                 ...  ...    ...
# 2013                           Transcript not available  ...   True
# 2022                           Transcript not available  ...   True
# 2026                           Transcript not available  ...   True
# 2036                           Transcript not available  ...  False
# 2037                           Transcript not available  ...   True
#
#      readability   tone  cultural_sensitivity  kids_safe_content  \
# 2          False  False                 False              False
# 3          False   True                 False              False
# 7          False   True                 False              False
# 9          False   True                 False              False
# 10         False   True                 False              False
# ...          ...    ...                   ...                ...
# 2013       False  False                 False              False
# 2022       False   True                 False              False
# 2026       False   True                 False              False
# 2036       False  False                 False              False
# 2037       False   True                 False              False
#
#                    profanity_words  \
# 2                             None
# 3     [suck, crap, hell, fat, god]
# 7                             None
# 9                [hell, god, dong]
# 10               [hell, god, damn]
# ...                            ...
# 2013                        [hell]
# 2022                          None
# 2026                          None
# 2036                          None
# 2037                          None
#
#                                       themes_identified  tone_score  \
# 2                                                  None     -0.2023
# 3     [boyfriend, adult, kill, sex, lingerie, war, c...      1.0000
# 7                                                 [war]      0.9136
# 9                             [escort, hell, fire, hot]      0.9998
# 10                         [hell, fire, damn, hot, gun]      0.9990
# ...                                                 ...         ...
# 2013  [scream, kill, nightmare, demon, haunted, hell...     -0.9792
# 2022                                           [zombie]      0.9559
# 2026                                    [vampire, lust]      0.9001
# 2036                                               None     -0.5719
# 2037                                   [kill, gun, die]      0.9162
#
#       contains_cultural_sensitivity cultural_sensitivity_identified
# 2                             False                              []
# 3                             False                              []
# 7                             False                              []
# 9                             False                              []
# 10                            False                              []
# ...                             ...                             ...
# 2013                          False                              []
# 2022                          False                              []
# 2026                          False                              []
# 2036                          False                              []
# 2037                          False                              []
#
# [1023 rows x 24 columns]

# %%
filtered_df.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_title',
#        'tags', 'category_id', 'category_label', 'default_audio_language',
#        'transcript', 'text_dict', 'combined_text', 'kids_safe_BERT',
#        'profanity', 'themes', 'readability', 'tone', 'cultural_sensitivity',
#        'kids_safe_content', 'profanity_words', 'themes_identified',
#        'tone_score', 'contains_cultural_sensitivity',
#        'cultural_sensitivity_identified'],
#       dtype='object')

# %%
filtered_df = filtered_df.drop(columns=["description", "tags", "default_audio_language", "transcript", "text_dict", "combined_text"])

print(filtered_df.head())  # View the modified DataFrame
# Out:
#        video_id                                              title  \
# 2   ZQbWWOzvyfo                                            Verizon
# 3   u4gEBRSKi2E  Is Being Fat A Choice? Fit Women vs Fat Women ...
# 7   T5niXqwAnME  Big Muscle Guy Scars RELEASED #health #muscles...
# 9   mHZRFs-faX8              Cooking Curry During College Lecture!
# 10  yeSbUxW2M-4                   clips that made Kai Cenat famous
#
#             published_at           channel_title  category_id  \
# 2   2024-07-03T02:03:05Z                 Verizon           28
# 3   2024-10-16T16:01:03Z                 Jubilee           24
# 7   2024-06-14T13:30:15Z  Mondragon Chiropractic           27
# 9   2024-10-13T02:00:02Z                  Fique            24
# 10  2022-12-31T17:00:38Z          Kai Cenat Live           24
#
#           category_label  kids_safe_BERT  profanity  themes  readability  \
# 2   Science & Technology               0      False   False        False
# 3          Entertainment               0       True    True        False
# 7              Education               0      False    True        False
# 9          Entertainment               0       True    True        False
# 10         Entertainment               0       True    True        False
#
#      tone  cultural_sensitivity  kids_safe_content  \
# 2   False                 False              False
# 3    True                 False              False
# 7    True                 False              False
# 9    True                 False              False
# 10   True                 False              False
#
#                  profanity_words  \
# 2                           None
# 3   [suck, crap, hell, fat, god]
# 7                           None
# 9              [hell, god, dong]
# 10             [hell, god, damn]
#
#                                     themes_identified  tone_score  \
# 2                                                None     -0.2023
# 3   [boyfriend, adult, kill, sex, lingerie, war, c...      1.0000
# 7                                               [war]      0.9136
# 9                           [escort, hell, fire, hot]      0.9998
# 10                       [hell, fire, damn, hot, gun]      0.9990
#
#     contains_cultural_sensitivity cultural_sensitivity_identified
# 2                           False                              []
# 3                           False                              []
# 7                           False                              []
# 9                           False                              []
# 10                          False                              []

# %%
import datetime

# Get the current datetime and format it
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Save the DataFrame to an Excel file
excel_file_name = f"../data/raw/video_information_with_transcripts_network{current_time}.xlsx"
filtered_df.to_excel(excel_file_name, index=False)

# Save the DataFrame to a JSON file
json_file_name = f"../data/raw/video_information_with_transcripts_network{current_time}.json"
filtered_df.to_json(json_file_name, orient="records", lines=True)

print(f"Analysis complete. Results saved to '{excel_file_name}' and '{json_file_name}'.")
# Out:
# Analysis complete. Results saved to '../data/raw/video_information_with_transcripts_network2024-12-13_19-39-57.xlsx' and '../data/raw/video_information_with_transcripts_network2024-12-13_19-39-57.json'.
