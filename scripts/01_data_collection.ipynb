# %%
# !pip install google-api-python-client youtube-transcript-api pandas openpyxl

# %% [markdown]
# ##  Import Required Libraries

# %%
# Import necessary libraries
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, NoTranscriptFound
import pandas as pd
import time
import random
import sys
import os

# %% [markdown]
# # Data collection from YoutubeAPI

# %%
# Add the parent directory (where config.py resides) to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

try:
    from config import API_KEY
except ImportError as e:
    raise RuntimeError(f"API key not found! Ensure 'config.py' exists in the parent directory. Error: {e}")

# Set up the YouTube Data API client
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Function to fetch video categories
def get_video_categories(region_code="US"):
    categories = {}  # Declare categories as a local dictionary to return
    try:
        request = youtube.videoCategories().list(
            part="snippet",
            regionCode=region_code
        )
        response = request.execute()
        for item in response.get("items", []):
            categories[item["id"]] = item["snippet"]["title"]
    except Exception as e:
        print(f"Error fetching video categories: {e}")
    return categories

# Function to fetch video IDs for a specific category with children-friendly content
def fetch_video_ids_for_kids_category(category_id, max_results=10):
    video_ids = []
    try:
        # Fetch videos with strict safe search enabled for children-friendly content
        request = youtube.search().list(
            part="id",
            type="video",
            videoCategoryId=category_id,
            maxResults=max_results,
            # safeSearch='strict'  # Ensures children-friendly videos
        )
        response = request.execute()
        for item in response.get("items", []):
            video_ids.append(item["id"]["videoId"])
        
        # Shuffle to ensure randomness if required
        random.shuffle(video_ids)
        video_ids = video_ids[:max_results]  # Restrict to the desired number of results
    except Exception as e:
        print(f"Error fetching video IDs for category {category_id}: {e}")
    return video_ids

# Function to fetch video IDs for a specific category
def fetch_video_ids_for_category(category_id, max_results=10):
    video_ids = []
    try:
        request = youtube.search().list(
            part="id",
            type="video",
            videoCategoryId=category_id,
            maxResults=50  # Fetch more than 10 to enable random selection
        )
        response = request.execute()
        for item in response.get("items", []):
            video_ids.append(item["id"]["videoId"])
        
        # Randomly shuffle the video IDs and pick the first `max_results` video IDs
        random.shuffle(video_ids)
        video_ids = video_ids[:max_results]
    except Exception as e:
        print(f"Error fetching video IDs for category {category_id}: {e}")
    return video_ids

# Function to fetch video metadata
def get_video_metadata(video_ids):
    metadata = []
    try:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=",".join(video_ids)
        )
        response = request.execute()
        for video in response.get("items", []):
            snippet = video.get("snippet", {})
            content_details = video.get("contentDetails", {})
            statistics = video.get("statistics", {})
            
            metadata.append({
                "video_id": video.get("id"),
                "title": snippet.get("title", ""),
                "description": snippet.get("description", ""),
                "published_at": snippet.get("publishedAt", ""),
                "channel_title": snippet.get("channelTitle", ""),
                "tags": ", ".join(snippet.get("tags", [])) if snippet.get("tags") else "",
                "category_id": snippet.get("categoryId", ""),
                "duration": content_details.get("duration", ""),
                "view_count": statistics.get("viewCount", 0),
                "like_count": statistics.get("likeCount", 0),
                "dislike_count": statistics.get("dislikeCount", 0),
                "default_audio_language": snippet.get("defaultAudioLanguage", ""),
            })
    except Exception as e:
        print(f"Error fetching metadata: {e}")
    return metadata

# Function to fetch video transcript
def get_video_transcript(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])
        transcript_text = " ".join([t['text'] for t in transcript])
        return transcript_text
    except NoTranscriptFound:
        return ""
    except Exception as e:
        print(f"Error fetching transcript for {video_id}: {e}")
        return ""

# Step 2: Collect 10 random videos per category
VIDEOS_PER_CATEGORY = 5
BATCH_SIZE = 10  # Define batch size for processing metadata
all_data = []

# %% [markdown]
# ## Fetch all category without kids safe

# %%
# Step 1: Fetch all YouTube categories
categories = get_video_categories()
print(f"Found {len(categories)} categories: {categories}")

for category_id, category_name in categories.items():
    print(f"Collecting data for category: {category_name} (ID: {category_id})")
    video_ids = fetch_video_ids_for_category(category_id, max_results=VIDEOS_PER_CATEGORY)
    video_ids = fetch_video_ids_for_kids_category(category_id, max_results=VIDEOS_PER_CATEGORY)
    print(f"Collected {len(video_ids)} video IDs for category {category_name}.")
    
    # Fetch metadata and transcripts in batches
    for i in range(0, len(video_ids), BATCH_SIZE):
        batch_ids = video_ids[i:i+BATCH_SIZE]
        
        # Fetch metadata
        metadata = get_video_metadata(batch_ids)
        
        # Fetch transcripts
        for item in metadata:
            video_id = item["video_id"]
            transcript = get_video_transcript(video_id)
            item["transcript"] = transcript
        
        all_data.extend(metadata)
        print(f"Processed {i + len(batch_ids)} / {len(video_ids)} videos for category {category_name}.")
        time.sleep(random.uniform(1, 3))  # Pause to avoid rate limits
# Out:
# Found 32 categories: {'1': 'Film & Animation', '2': 'Autos & Vehicles', '10': 'Music', '15': 'Pets & Animals', '17': 'Sports', '18': 'Short Movies', '19': 'Travel & Events', '20': 'Gaming', '21': 'Videoblogging', '22': 'People & Blogs', '23': 'Comedy', '24': 'Entertainment', '25': 'News & Politics', '26': 'Howto & Style', '27': 'Education', '28': 'Science & Technology', '29': 'Nonprofits & Activism', '30': 'Movies', '31': 'Anime/Animation', '32': 'Action/Adventure', '33': 'Classics', '34': 'Comedy', '35': 'Documentary', '36': 'Drama', '37': 'Family', '38': 'Foreign', '39': 'Horror', '40': 'Sci-Fi/Fantasy', '41': 'Thriller', '42': 'Shorts', '43': 'Shows', '44': 'Trailers'}
# Collecting data for category: Film & Animation (ID: 1)
# Collected 5 video IDs for category Film & Animation.
# Error fetching transcript for lTjkFcVlypQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=lTjkFcVlypQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Film & Animation.
# Collecting data for category: Autos & Vehicles (ID: 2)
# Collected 5 video IDs for category Autos & Vehicles.
# Processed 5 / 5 videos for category Autos & Vehicles.
# Collecting data for category: Music (ID: 10)
# Collected 5 video IDs for category Music.
# Error fetching transcript for pfiCNAc2AgU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pfiCNAc2AgU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for pRGeYjd0-qM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pRGeYjd0-qM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for JKGPjoJBd3o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JKGPjoJBd3o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for XszsV5rx4Xo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=XszsV5rx4Xo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Music.
# Collecting data for category: Pets & Animals (ID: 15)
# Collected 5 video IDs for category Pets & Animals.
# Processed 5 / 5 videos for category Pets & Animals.
# Collecting data for category: Sports (ID: 17)
# Collected 5 video IDs for category Sports.
# Error fetching transcript for 8YHWi6mKdfc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8YHWi6mKdfc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for Bd5OtxXIkY4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Bd5OtxXIkY4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for YoKFySaQ8tA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YoKFySaQ8tA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for dknmnnqfb38:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dknmnnqfb38! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for EnekP4xp3UY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EnekP4xp3UY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Sports.
# Collecting data for category: Short Movies (ID: 18)
# Collected 0 video IDs for category Short Movies.
# Collecting data for category: Travel & Events (ID: 19)
# Collected 5 video IDs for category Travel & Events.
# Processed 5 / 5 videos for category Travel & Events.
# Collecting data for category: Gaming (ID: 20)
# Collected 5 video IDs for category Gaming.
# Processed 5 / 5 videos for category Gaming.
# Collecting data for category: Videoblogging (ID: 21)
# Collected 0 video IDs for category Videoblogging.
# Collecting data for category: People & Blogs (ID: 22)
# Collected 5 video IDs for category People & Blogs.
# Error fetching transcript for -SPtHMA-XEg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-SPtHMA-XEg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category People & Blogs.
# Collecting data for category: Comedy (ID: 23)
# Collected 5 video IDs for category Comedy.
# Processed 5 / 5 videos for category Comedy.
# Collecting data for category: Entertainment (ID: 24)
# Collected 5 video IDs for category Entertainment.
# Error fetching transcript for 0KZBBYhtbpI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0KZBBYhtbpI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for K6YkluRIUCY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=K6YkluRIUCY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for DFKnq_bCU8Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=DFKnq_bCU8Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Entertainment.
# Collecting data for category: News & Politics (ID: 25)
# Collected 5 video IDs for category News & Politics.
# Error fetching transcript for PeAYVBnfACk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PeAYVBnfACk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for OzwSMHH9sEk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OzwSMHH9sEk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category News & Politics.
# Collecting data for category: Howto & Style (ID: 26)
# Collected 5 video IDs for category Howto & Style.
# Processed 5 / 5 videos for category Howto & Style.
# Collecting data for category: Education (ID: 27)
# Collected 5 video IDs for category Education.
# Error fetching transcript for dGHLqaiaTGA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=dGHLqaiaTGA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for FvLulH-LU88:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FvLulH-LU88! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Education.
# Collecting data for category: Science & Technology (ID: 28)
# Collected 5 video IDs for category Science & Technology.
# Processed 5 / 5 videos for category Science & Technology.
# Collecting data for category: Nonprofits & Activism (ID: 29)
# Collected 5 video IDs for category Nonprofits & Activism.
# Error fetching transcript for f4P9JBJ1BpU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=f4P9JBJ1BpU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Nonprofits & Activism.
# Collecting data for category: Movies (ID: 30)
# Collected 5 video IDs for category Movies.
# Error fetching transcript for 2ZwZJXOL2EM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2ZwZJXOL2EM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for KpTiU2ilDos:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KpTiU2ilDos! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for v3-YSS1Js9A:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=v3-YSS1Js9A! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for IzfvY5kwefE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=IzfvY5kwefE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Movies.
# Collecting data for category: Anime/Animation (ID: 31)
# Collected 5 video IDs for category Anime/Animation.
# Error fetching transcript for HSQI0fSN8pU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HSQI0fSN8pU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 307G8rmDYec:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=307G8rmDYec! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 3hxV41P94js:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3hxV41P94js! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for tLvk0MXLRkY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tLvk0MXLRkY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 1O_qkM9_5Gw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1O_qkM9_5Gw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Anime/Animation.
# Collecting data for category: Action/Adventure (ID: 32)
# Collected 5 video IDs for category Action/Adventure.
# Processed 5 / 5 videos for category Action/Adventure.
# Collecting data for category: Classics (ID: 33)
# Collected 1 video IDs for category Classics.
# Error fetching transcript for evYan65Xs7Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=evYan65Xs7Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 1 / 1 videos for category Classics.
# Collecting data for category: Comedy (ID: 34)
# Collected 5 video IDs for category Comedy.
# Error fetching transcript for t3V25dbR8pk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=t3V25dbR8pk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 2UDLsA0OHRM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2UDLsA0OHRM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for S_DmOX1tW4M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=S_DmOX1tW4M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Comedy.
# Collecting data for category: Documentary (ID: 35)
# Collected 4 video IDs for category Documentary.
# Error fetching transcript for mSibnoRNIC8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mSibnoRNIC8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for zH9ExGUm7IA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zH9ExGUm7IA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for R4tW6-8Cgg8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=R4tW6-8Cgg8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 4 / 4 videos for category Documentary.
# Collecting data for category: Drama (ID: 36)
# Collected 5 video IDs for category Drama.
# Error fetching transcript for AAKIrVyGidY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AAKIrVyGidY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 6lVQT-0TPi4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6lVQT-0TPi4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for Hske7abHXO8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Hske7abHXO8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Drama.
# Collecting data for category: Family (ID: 37)
# Collected 5 video IDs for category Family.
# Error fetching transcript for QeozWoGmsdw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=QeozWoGmsdw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Family.
# Collecting data for category: Foreign (ID: 38)
# Collected 0 video IDs for category Foreign.
# Collecting data for category: Horror (ID: 39)
# Collected 2 video IDs for category Horror.
# Error fetching transcript for hnlA1tsY-lI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hnlA1tsY-lI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for wk3pggOhHHA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=wk3pggOhHHA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 2 / 2 videos for category Horror.
# Collecting data for category: Sci-Fi/Fantasy (ID: 40)
# Collected 0 video IDs for category Sci-Fi/Fantasy.
# Collecting data for category: Thriller (ID: 41)
# Collected 1 video IDs for category Thriller.
# Error fetching transcript for 1o-oWUCpTKQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1o-oWUCpTKQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 1 / 1 videos for category Thriller.
# Collecting data for category: Shorts (ID: 42)
# Collected 5 video IDs for category Shorts.
# Error fetching transcript for pkpwNwAPNTw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pkpwNwAPNTw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for gK94jFWhRkk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gK94jFWhRkk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for CpvVYLuGSi0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CpvVYLuGSi0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for jaHhrsDUbtM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jaHhrsDUbtM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Shorts.
# Collecting data for category: Shows (ID: 43)
# Collected 5 video IDs for category Shows.
# Error fetching transcript for QM0uJ_SZaOc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=QM0uJ_SZaOc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for ANyC63ajzcc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ANyC63ajzcc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for yZHw5Qf5Mp8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yZHw5Qf5Mp8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for fF0PJctMp1Y:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fF0PJctMp1Y! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for ZvmtsdhZo2U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZvmtsdhZo2U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Shows.
# Collecting data for category: Trailers (ID: 44)
# Collected 5 video IDs for category Trailers.
# Error fetching transcript for RTDfhNxv6uU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=RTDfhNxv6uU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for e-s_t1nExk8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=e-s_t1nExk8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for Eq-7ry44r5I:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Eq-7ry44r5I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for Ecn8dvDK7LQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Ecn8dvDK7LQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for 71rDQ7z4eFg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=71rDQ7z4eFg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Processed 5 / 5 videos for category Trailers.

# %% [markdown]
# ## Fetch only kids category video with safeSearch attribute

# %%
# Fetch only kids safe content:
category_id = 24
video_ids = fetch_video_ids_for_kids_category(category_id, max_results=VIDEOS_PER_CATEGORY)
# print(f"Collected {len(video_ids)} video IDs for category {category_name}.")

# Fetch metadata and transcripts in batches
for i in range(0, len(video_ids), BATCH_SIZE):
    batch_ids = video_ids[i:i+BATCH_SIZE]
    
    # Fetch metadata
    metadata = get_video_metadata(batch_ids)
    
    # Fetch transcripts
    for item in metadata:
        video_id = item["video_id"]
        transcript = get_video_transcript(video_id)
        item["transcript"] = transcript
    
    all_data.extend(metadata)
    # print(f"Processed {i + len(batch_ids)} / {len(video_ids)} videos for category {category_name}.")
    time.sleep(random.uniform(1, 3))  # Pause to avoid rate limits

all_data
# Out:
# Error fetching transcript for FYiQmFGRHd8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FYiQmFGRHd8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Error fetching transcript for efp3sv7t1RQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=efp3sv7t1RQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [{'video_id': 'OGUDOc-EvGI',
#   'title': "WE'RE MAKING A MANGA",
#   'description': "Manga Contest Details: https://wordlessmanga.com/eng.html\nManga Contest FAQ: https://x.com/KADOKAWAdigipub/status/1866081205290205245\nJoin our Patreon! https://www.patreon.com/spilledinkling\nDaidus'  main channel:  @Daidus  \nDaidus' Twitter: https://twitter.com/Daidus_OTL\nDaidus' Instagram: https://www.instagram.com/daidus_art/?hl=en\nEmirichu's main channel:  @Emirichu  \nEmily's Twitter: https://twitter.com/EmirichuYT\nEmily's Instagram: https://www.instagram.com/emirichuu/?hl=en\n\nSPILLED INK! Instagram: https://www.instagram.com/spilledinkling?igsh=MTdyb2Y0cHBsNm5rNg%3D%3D&utm_source=qr\n\nEdited by the Mudan Media Group @marukudeibu \n\nEpisode 32",
#   'published_at': '2024-12-09T14:56:27Z',
#   'channel_title': 'Spilled Ink',
#   'tags': 'manga, manga contest, manga competition, drawing, drawing manga, drawing anime, anime, original manga, tradtional manga, rough draft, name, art, manga editor, kadokawa',
#   'category_id': '24',
#   'duration': 'PT1H2M41S',
#   'view_count': '170999',
#   'like_count': '14398',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': "hello and welcome to another episode of spilling with your host emirichu [Music] andus and today we have a very special episode for you because we are going to be working on some manga manga let's go some people have been asking for this so I'm very excited for this episode finally we'll be working on our submission for the wordless World Manga contest hosted by C kala and for those of you who are unfamiliar Cala is our parent company but it's also a multimedia company that does publishing anime games and more for titles like ni Joe rezero OKO dungeon Mesi and konosuba so many more there's a lot of lot of recognizable titles and due to the contest's wordless nature anyone from any country can participate without having to worry about language barriers which means that's right dear viewer you you can join in on this contest if you want so if you're like us and you have ever dreamed of one day publishing your own manga or even just having a manga editor look at your work this now is your chance this is the perfect opportunity there will be a prize pool of $36,000 us so you can check out the link in the description SL pinned comment for more details and lastly the contest admission deadline is on February 28th 20125 which is a couple months from now so you have some time but you know you should get started because that that time catches up and you guys know art takes a lot of time very excited what do we have today and guess who's also joining the contest us that's right U and dius is joined the contest also so yeah you we could win I I don't think so we could I don't know about I hope we win do you anyways what we have here is that we have a bunch of rough names and name is basically just a Japanese word for rough manga where you panel you show the panels you showcase your your the most messiest sketches just trying to get the point across and we are going to present to you our ideas of a plot and characters and all that jazz I think we've seen manga names before right at like manga exhibits pretty cool you know what what is difficult while we're doing this for 3 days straight in all those cafes we went to cafes and we just we went manga mode and we're just like a little Cor was really hard it was hard but very fun but what I learned while doing it is that the wordless thing is so hard it makes it so much more difficult I so badly wanted to use a speech bubble that just said this is this place or this does that and I'm like nope you can't nope nope no no it makes you realize like how much you need the context of like actual words yeah so now it just feels like we're just storyboarding for like an animatic or something yeah anyways so I'll showcase mine and then Emily will showcase hers and we'll explain since it's worthless we'll explain each panel and go along so this this is what we're going to be showing to the kadokawa manga editor so that's the other exciting part we're going to have our rough draft looked at by an actual manga editor so they're going to tell us what changes we could probably do so this is not what we're submitting this is just like step one basically and we're going to poop ourselves as they look over our uh our works and judge it accordingly ass go back to the I'm going to suck new manga new manga all right I will go first mhm and what we have here is just a notebook so it can it looks like a manga I guess as you're flipping it so are you going to give like a one sentence synopsis or are you just going to go balls balls deep I'm going balls deep I'm just going to explain what's happening on each panel and hopefully you guys could tell and the that the editor that's about to look over my manga I hope she understands what I'm drawing that's my main concern we got squid closeup of a squid looks good and then DUS is chewing something and he's looking at the squid obviously I hope that's easy to read M and then here we are it it's not you know this is by the way this is a rough okay this is no ...
#  {'video_id': 'FYiQmFGRHd8',
#   'title': '3년 6개월 만에 돌아온 트와이스 스춤 | STUDIO CHOOM ORIGINAL',
#   'description': '3년 6개월 만에 돌아온 트와이스 스춤 | STUDIO CHOOM ORIGINAL\n\nStream various performance video on #STUDIOCHOOM!\n\n👉SUBSCRIBE👈\nYouTube: https://www.youtube.com/STUDIOCHOOM\nFacebook:  https://www.facebook.com/StudioCHOOM\nInstagram: https://www.instagram.com/studio_choom/\nNaver TV: https://tv.naver.com/cjenm.STUDIOCHOOM',
#   'published_at': '2024-12-10T14:00:14Z',
#   'channel_title': 'STUDIO CHOOM [스튜디오 춤]',
#   'tags': 'M2, 엠투, 스튜디오 춤, 스춤, Studio choom, COVERS, 커버스, DANCE THE X, 댄스 더 엑스, 댄스, DANCE, 비 오리지널, BE ORIGINAL, 커버, COVER, Artist Of The Month, AOTM, Drop the dance, 드롭더댄스, Mix & Max, 믹스앤맥스, 믹앤맥',
#   'category_id': '24',
#   'duration': 'PT29S',
#   'view_count': '151510',
#   'like_count': '17716',
#   'dislike_count': 0,
#   'default_audio_language': 'ko',
#   'transcript': ''},
#  {'video_id': 'vTxck5VqYis',
#   'title': "The Sliders Get Rated by Chef Ramsay & David Myers | Hell's Kitchen",
#   'description': "Chef Ramsay &amp; Michelin star chef David Myers rate chefs' sliders.\n\n🔥 SHOP\nHell's Kitchen Hybrid Cookware brings performance cooking to your kitchen. Shop now at:  https://bit.ly/hellskitchen-store\n\n🔥 SUBSCRIBE\nSubscribe now to not miss out on the best clips, compilations and episodes: https://bit.ly/hellskitchen-subscribe\n\n__________________________________________\n\n🔥 EPISODIC INFO\nThis clip is from: https://www.youtube.com/playlist?list=PL4eV63y2JNDE5aoSo4o21ewf_JV_Vt_vS - Episode 4\n\n🔥 ABOUT THE SHOW\nIn Hell's Kitchen, two teams compete for the prestigious job of head chef at a top restaurant, all under the guidance of world-class fiery chef Gordon Ramsay.",
#   'published_at': '2024-12-10T17:01:02Z',
#   'channel_title': "Hell's Kitchen",
#   'tags': "Hell’s kitchen, hells kitchen us, gordon Ramsay, hells kitchen, hell's kitchen full episodes, hells kitchen full episodes, hells kitchen best moments, hells kitchen funny moments, Gordon Ramsay, Hell’s Kitchen insults, lamb sauce, hells kitchen official, Gordon Ramsey, Christina Wilson, Jay Santos, Uncensored, Battle of the Ages, Alex Belew, Dafne Mejia, Alejandro Najar, Sommer Sellers, Cheyenne Nichols, Tara Ciannella, Season 21, S21, Vlad Briantsev, Zeus Gordiany, S21E04",
#   'category_id': '24',
#   'duration': 'PT8M27S',
#   'view_count': '96609',
#   'like_count': '2062',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': '- Right, ladies,\nwhose chicken am I tasting? - Mine, Chef.\n- Gentlemen. - Chef, we\'re tasting mine. - Interesting.\nWhose lamb am I tasting? - Mine, Chef.\n- Mine, Chef. - Okay, and whose\nsalmon burger am I tasting? - Chef, we\'re gonna go\nwith my salmon. - Salmon, we decided Abe\'s.\n- Okay. So clearly Brett\'s.\nWe\'re tasting the beef burger. Red Team. - It\'s up to you.\n- Mine, Chef. - I\'m just so confused\nby Sommer. - Are you okay with that?\n- That\'s fine. - Why are you letting Nicole\nput her dish up over yours when we know nothing\nabout her other than she blows challenges? - Okay. To help me judge\nthese sliders, an amazing, award-winning,\ninternationally renowned chef, three Michelin stars. Please, all of you,\ngive a warm welcome for Chef David Myers. [applause] - Wow. David Myers is\nincredibly handsome. - Welcome back\nto "Hell\'s Kitchen." - Thanks so much, Chef. - We\'ll be judging your sliders\nfrom one to three stars. Shall we start off\nwith the chicken sliders? Let\'s go.\nBlue Team first, please. Alejandro. - I\'m so excited to have\nmy food tasted by David Myers. I feel like I knocked it\nout of the park, so I\'m ready to win. - Alejandro,\ndescribe your slider. - I fried the prosciutto\nand then candied it, and I essentially made, like, a quick marmalade\ncaramel sauce. - Mmm, well, I like the\nmarmalade idea with prosciutto. It\'s clever.\n- Thank you, Chef. - Really, really clever.\n- Yes, Chef. - Personally, go a bit thicker.\n- Yeah. - Because it\'s just\na little bit too thin. Ready to vote?\n- Let\'s do it. There we go. Two stars. Bravo, Chef. Bravo.\n- Thank you. - Right, chicken, Red Team.\nAlyssa. Thank you. - Hi.\n- Wow, look at that. - So today, you have\na ground chicken burger. I used the poblano\nand mango chutney. - Tough one, that mango\nin the chicken slider. - Yeah, real challenging.\n- Yeah. - But I took the challenge,\nChef, and I made it work, and I think it\'s delicious. I hope you enjoy. - I like what you\'ve done with the flavor\nof the chicken patty. I mean, it really explodes,\nand the mango actually works with it.\n- Thank you, Chef. - I think you\'ve done\na great job on this. - Thank you.\n- Really good. Shall we?\n- Let\'s do it. [applause] Thank you, Chef.\n- Bravo. That was a hard one. - Boom. That is mine. It is an A-plus game\nright there. - You needed that.\n- Wow, what a start. - See what I can do?\n- Salmon from the Blue Team. narrator: While Abe tries\nto post a big score with his salmon slider\ntopped with fried capers and citrus caviar whip... - That is good.\n- Thank you, Chef. - Very good. Shall we? [cheers and applause] - Go, baby! narrator: Dafne serves up\nher poached salmon slider with black garlic\nand pickled fennel. - Pickled fennel. You nailed it.\n- Thank you, Chef. - Be careful, because it\'s\nquite dense inside, and so it\'s hard. - Thank you so much. - All right. - We got this, you guys.\nWe got this. narrator: Up next... - Vlad, let\'s go please,\na lamb burger. narrator: The Blue Team\nhas chosen Vlad and his lamb slider\ntopped with spinach to be judged over Billy\'s\npesto lamb slider. - The spinach is\nliterally soaking wet. - I\'m not getting a lot\nof flavor in the lamb. - Thank you, Vlad.\n- Yes, Chef. - I am severely\nbutt hurt central. Vlad, you pull out a two, dog? I told you so, bro. narrator: And Tara presents\nher prosciutto and blue cheese stuffed\nlamb sliders. - So the blue cheese\ncompletely overwhelms lamb. - Lamb and blue cheese doesn\'t\ngo together for a reason. - Thank you, Chef.\n- Nice try. - Yeah.\n- Nice try, Chef. - That crushes me. Blue cheese and lamb?\nI knew it was a risk. - Thank you, Tara.\nWhat a shame. - But I did not want to be\nthe one to get two stars my first day on the Red Team. - Ladies in the lead, 11 to 12. - Wow, this is tough. - And it\'s down to the beef.\nBlue Team. Brett, please come forward\nand serve David and I. - Let\'s go, Brett! - Describe the burgers, please. - So you ha ...
#  {'video_id': 'mcvLKldPM08',
#   'title': '28 YEARS LATER – Official Trailer (HD)',
#   'description': "What will humanity become?\n\nDanny Boyle and Alex Garland reunite for #28YearsLater - only in theatres 6.20.25.\n\nFollow Us on Social:\nhttps://x.com/28YearsLaterMov\nhttps://www.facebook.com/28yearslaterofficial\nhttps://www.instagram.com/28yearslatermovie\nhttps://www.tiktok.com/@28yearslatermovie \n\nSign up to get notified when 28 DAYS LATER is available to preorder: https://bit.ly/28DaysLaterGetNotified  \n\nSubscribe for more exclusive content: https://www.youtube.com/@sonypictures\n\nAcademy Award®-winning director Danny Boyle and Academy Award®-nominated writer Alex Garland reunite for 28 Years Later, a terrifying new story set in the world created by 28 Days Later. It’s been almost three decades since the rage virus escaped a biological weapons laboratory, and now, still in a ruthlessly enforced quarantine, some have found ways to exist amidst the infected. One such group of survivors lives on a small island connected to the mainland by a single, heavily-defended causeway. When one of the group leaves the island on a mission into the dark heart of the mainland, he discovers secrets, wonders, and horrors that have mutated not only the infected but other survivors as well.\n \nDirected by:\u200b\u200b\nDanny Boyle\u200b\u200b\u200b\n\u200b\nWritten by:\u200b\u200b\u200b\u200b\nAlex Garland\u200b\u200b\u200b\n \nProduced by: \u200b\u200b\u200b\u200b\nAndrew Macdonald\n\u200b\u200b\u200b\u200b\u200bPeter Rice\n\u200b\u200b\u200b\u200b\u200bBernard Bellew\nDanny Boyle\nAlex Garland\n \nExecutive Producer:\u200b\u200b\u200b\nCillian Murphy\n \nCast:\u200b\nJodie Comer\n\u200bAaron Taylor-Johnson\n\u200bJack O'Connell\n\u200bAlfie Williams\n\u200band Ralph Fiennes\n \nThis film is not yet rated by The Motion Picture Association. For future rating information, please visit www.filmratings.com.\n \nCredits not final\n\n#SonyPictures #Trailer #MovieTrailer #28YearsLater #28DaysLater #28MonthsLater #DannyBoyle\u200b\u200b\u200b #AlexGarland\u200b\u200b\u200b #CillianMurphy #JodieComer #\u200bAaronTaylorJohnson #\u200bJackOConnell\n#\u200bAlfieWilliams #RalphFiennes",
#   'published_at': '2024-12-10T08:00:06Z',
#   'channel_title': 'Sony Pictures Entertainment',
#   'tags': '28 years later, 28 years later movie, movie, film, trailer, official trailer, 28 years later trailer, 28 years later official, clip, scene, cillian murphy, aaron taylor johnson, jodie comer, ralph fiennes, danny boyle, 28 years later cillian murphy, sony, sony pictures, summer, 2025',
#   'category_id': '24',
#   'duration': 'PT2M13S',
#   'view_count': '8852320',
#   'like_count': '341279',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "[Music] sit here Auntie what's going on do sit still keep quiet and do not move from this spot [Music] 7 6 11 5 9 and 20 miles today 4 11 17 32 the day before boot boot boot boot moving up and down again there's no discharge in the war don't don't don't don't look at what's in front of you boost boost boost boost moving up down again men men men men men go mad with watching him there's no discharge in the war if your eyes drop they will get a top of you boot boot boot boot moving up and down again there's no discharge in the wall the things are something different oh my heart keep me going lunatic Ming up and down again that no discharge in the world 7 6 11 5 4 1732 the day before"},
#  {'video_id': 'efp3sv7t1RQ',
#   'title': 'WHEN DIRTY COPS GET CAUGHT! JUDGE EXPOSES COPS EVERY TIME!',
#   'description': 'MUST SEE!',
#   'published_at': '2024-12-11T17:32:43Z',
#   'channel_title': 'Accountability For All',
#   'tags': '1st amendment audit, first amendment audit, 1st amendment audit fail, first amendment audit fail, accountability for all, id refusal, id refused, cop owned, cops owned, police, owned, destroyed, james freeman, lackluster',
#   'category_id': '24',
#   'duration': 'P0D',
#   'view_count': '1499',
#   'like_count': '322',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': ''},
#  {'video_id': 'p-VvS3LTpPU',
#   'title': 'We got to feed the lambs 🥹',
#   'description': '',
#   'published_at': '2024-12-10T18:05:48Z',
#   'channel_title': 'Connor And Liana',
#   'tags': '',
#   'category_id': '24',
#   'duration': 'PT1M',
#   'view_count': '299518',
#   'like_count': '42422',
#   'dislike_count': 0,
#   'default_audio_language': 'en-GB',
#   'transcript': "feed the Lambs I want put boy come on [Laughter] [Music] [Laughter] then W that was cool so excited come on there little legs we'll be there by lunch time yeah can you say by Hope by hope louder it's like feeding Podge in the morning isn't it go see the dicky birdies I've got to look up it's not about the way it looks it's about the way it feels what's brown and sticky that one yeah you already knows there was talking really there was talk you can hear the birdies tweeting don't squish it okay bird"},
#  {'video_id': 'O_W39r0B6DQ',
#   'title': 'കാളിദാസിന്റെ ഹെന്നക്ക് പാർവതി ജയറാമിന്റെ ഗംഭീര ഡാൻസ് 🤩 Kalidas Jayaram wedding Henna function',
#   'description': '',
#   'published_at': '2024-12-10T10:43:14Z',
#   'channel_title': 'Fun Cafe',
#   'tags': '',
#   'category_id': '24',
#   'duration': 'PT41S',
#   'view_count': '622980',
#   'like_count': '19207',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'Ih2Ydza7y9Q',
#   'title': 'AVENGERS 5 CHRIS EVANS ANNOUNCEMENT',
#   'description': "Avengers 5 Doomsday Chris Evans Marvel Announcement. Chris Evans Returns, New Character, Robert Downey Jr Doctor Doom's Avengers Explained. Evil Avengers, Evil Captain America, Avengers 5 Trailer & Avengers 6 Secret Wars ► https://bit.ly/AwesomeSubscribe\nDeadpool 4 Announcement https://www.youtube.com/watch?v=bmjy7YnGF-k&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nWolverine vs Hulk Announcement https://www.youtube.com/watch?v=OFcYECC34NQ&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nSuperman Teaser Trailer 2025 https://www.youtube.com/watch?v=Z0leTZVPKqA&list=PLOIeYdZ3QczwCLH9RIm-7ui56ameRYmdQ&index=7&pp=gAQBiAQB\nVenom 4 Announcement https://www.youtube.com/watch?v=317o8mrQTs8&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=7&pp=gAQBiAQB\nDeadpool 4 https://www.youtube.com/watch?v=_4Tu22c3lLw&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nThunderbolts Trailer https://www.youtube.com/watch?v=zaJpF9cCYb4&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nCaptain America Brave New World Trailer https://www.youtube.com/watch?v=MmZdnhkq0vc&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nFantastic Four Trailer https://www.youtube.com/watch?v=ganuq2_1GOU&list=PLOIeYdZ3QczwWT3yd94Xc6n-ooI85uV_u&index=1&pp=gAQBiAQB\nEmergency Awesome New Videos https://www.youtube.com/watch?v=FeOfhzu7ZdY&list=PLOIeYdZ3QczxQXxyV_2D8kuEs_QsuQIyJ&index=7\n\nCovering Avengers 5 Doomsday Chris Evans Returns Announcement. Chris Evans new Marvel character, not returning as his original Steve Rogers Captain America or Johnny Storm Human Torch from Fantastic Four like Deadpool and Wolverine recently. Other returning original Avengers Explained. Alternate Characters, Doctor Doom's Avengers Explained.\n\nAvengers 5 Teaser Marvel Comic Con 2024. Robert Downey Jr Doctor Doom, why Robert Downey Jr Returns, Iron Man Legacy, Fantastic Four Comic Con Teaser connection. Russo Brothers Return, Avengers 5 and Avengers 6 Secret Wars Comic Con Teaser. Hydra Captain America, Evil Captain America Explained.\n\nWhy Marvel is rebooting the MCU, all the marvel movies and disney plus marvel tv shows with Avengers 6 Secret Wars. And what's going to change with all the Avengers, New Iron Man, X-Men Mutants like Wolverine, Deadpool, Fantastic Four, Ghost Rider, Spider-Man and other characters marvel previous had not been able to use the way they wanted in previous movies\n\nMarvel Reboot and changes they're making to the upcoming Movies and Marvel TV Shows on Disney Plus. Marvel MCU Reboot Plans Explained. What Happened to Marvel, Disney Plus Streaming problems, and Fixing Marvel\n\nAvengers 6 Secret Wars Teaser and the future of Wolverine and X-Men in the MCU. Lots more Marvel Trailers soon Avengers 5 Doomsday Trailer, Thunderbolts Trailer, Avengers 6 Secret Wars Trailer, Captain America Brave New World Trailer & Fantastic Four Trailer videos!\n\nMy Kraven Movie Review will post wed. Star Wars Skeleton Crew Episode 3 video will post next. Creature Commandos Episode 3 later, and Henry Cavill Warhammer Announcement!\n\n\nArt via https://www.instagram.com/rahalarts\nChris Evans Hydra Captain America via https://www.youtube.com/voordeel-ts\n\n\nTwitch Channel https://twitch.tv/emergencyawesome\nTwitter  https://x.com/awesomemergency\nFacebook  https://facebook.com/emergencyawesome\nInstagram  https://instagram.com/emergencyawesome\nTumblr  https://robotchallenger.com\nMy Website https://emergencyawesome.com\n\n:: Video Playlists For Shows ::\n\nNew Emergency Awesome Videos https://www.youtube.com/playlist?list=PLOIeYdZ3QczxQXxyV_2D8kuEs_QsuQIyJ\nHouse of The Dragon Episodes https://www.youtube.com/playlist?list=PLOIeYdZ3QczxqJeNeCsF_ghizcTS9nM4X\nLoki Episodes https://www.youtube.com/playlist?list=PLOIeYdZ3Qczy8mUNqHU-35xtTd-JpJU3l\nThe Mandalorian Episodes https://www.youtube.com/playlist?list=PLOIeYdZ3QczzsN78nOjS-ABHwKaB7KONW\nGame of Thrones Episodes https://www.youtube.com/playlist?list=SPOIeYdZ ...
#   'published_at': '2024-12-10T17:55:09Z',
#   'channel_title': 'Emergency Awesome',
#   'tags': '',
#   'category_id': '24',
#   'duration': 'PT12M18S',
#   'view_count': '254843',
#   'like_count': '5610',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "Having a big audience for you. Must be a cool thing.\nGood for you. I'm excited. Good for you. You made it. Let's see how. Cause\nyou know. Fingers crossed. Welcome back everyone it's Charlie, Marvel just revealed\nChris Evans is finishing a new contract to return again in Avengers\nfive doomsday, this time as another new character. He won't be his original Captain America\nSteve Rogers from the main MCU. He won't be his Johnny Storm from Fantastic Four. Like we just saw during Deadpool and Wolverine. part of his new character is also tied to Robert Downey\nJr's Doctor Doom in their borrowing a story concept from what looks like Avengers Forever,\na comic book in the Kang storyline. that they would have been using when the Council of Kings was going to be the new main villain\nand they were still doing Avengers five is King Dynasty. so we'll break it all down because it also pays off. Another twist from the Captain America comics\nthat everyone was talking about several years ago, especially during Avengers Endgame\nwhen they had the big Hail Hydra moment. that Easter egg from endgame was actually based on the recent Secret\nEmpire Captain America comics. Not to be confused with Secret Invasion. nobody. Nobody wants to remember a secret invasion. So it also involves the original Avengers actors\ncoming back to even the ones who died. So we'll break it all down. If you're brand new to the channel\nbe sure to subscribe to get all the videos. The reason why they're announcing so many big Avengers,\nfive doomsday things right now is because we're getting ready to start production\nearly next year, and they have to finish all the contracts for all these other big actors that are coming back,\nlike Chris Evans, for instance, in The other Avengers. but if you didn't see the news. Yesterday, while I was busy doing a video for Ryan\nReynolds and Andrew Garfield talking about the future of Deadpool and Spider-Man, the MCU, literally,\nlike while I was finishing that video, Marvel also revealed that they're bringing Chris Evans back again\nas another different character for Avengers five. Now, he might also be signing a contract\nto come back for Avengers six Secret Wars. Most of the news was just focusing on Avengers\nfive, though. part of the idea is that the plot for Avengers five\nwill be very different from the plot for Avengers six. It'll be a little bit like Avengers Infinity War\nand Avengers Endgame, where technically it's like one giant story divided into two parts\nthat they just released in back to back years. but when I say Chris Evans\nnew character is an Easter egg for Avengers Forever in the Secret Empire comics from Captain\nAmerica is basically an evil version of Captain America. Secret Empire was Hydra Captain America, who was a\ndifferent spin from Avengers Forever Evil Captain America. But for the purpose of these movies like Avengers five,\nyou just consider him an evil version of Captain America. Steve Rogers. same basic type of twist,\nlike what if Steve Rogers Captain America were evil instead of the most noble character\nyou could possibly imagine in the MCU? The way they explain him, he's\nmeant to be the soul of the Avengers. what if he showed up? But he was a very, very evil version of that. part of the idea is the Chris\nEvans is supposed to be returning in Avengers five with Robert Downey\nJr in the other original six Avengers characters. But here's the thing. Some of them will be coming back as part of an evil Avengers team controlled by Robert Downey\nJr as Doctor Doom from the multiverse. Like he'll be controlling his own evil Avengers team\nthat will just absolutely wipe the new MCU Avengers. So you got to see the parallels\nhere, like the twist that they're going for on screen, the reactions they're looking for from the audience, like,\noh, it's all our heroes. All our friends are back that we thought were either dead\nor retired, like Old Man Cap. you imagine how they're going to reac ...
#  {'video_id': 'dJsssNaTYKs',
#   'title': 'I think we will start seeing criminals use drones for hits in the future. #military #soldier',
#   'description': '',
#   'published_at': '2024-12-10T15:50:18Z',
#   'channel_title': 'Kagan Dunlap',
#   'tags': '',
#   'category_id': '24',
#   'duration': 'PT20S',
#   'view_count': '116365',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "so I honestly can't definitively say whether or not this takes place in Ukraine or not other than the logo at the top left corner but this could very easily be some gangsters taking somebody out which I'm sure is not out of the realm of possibilities down the road in the future because I guarantee they can get their hands on the same technology that the ukrainians can get their hands on"},
#  {'video_id': 'RCvCFjAlVKw',
#   'title': "Taeha the little boy didn't choose Jin over his father 😭",
#   'description': '',
#   'published_at': '2024-12-10T14:33:17Z',
#   'channel_title': 'Butter BTS k-pop',
#   'tags': '',
#   'category_id': '24',
#   'duration': 'PT29S',
#   'view_count': '109993',
#   'like_count': '16802',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''}]

# %% [markdown]
# ## Save the dataframe

# %%
all_data
# Out:
# [{'video_id': 'lTjkFcVlypQ',
#   'title': '🔴 LIVE! Phineas and Ferb Season 1 Full Episodes! | @disneyxd',
#   'description': 'Ferb! I know what we\'re gonna do today! Watch the full first season of Phineas and Ferb! While you\'re watching all the episodes from season 1, find Perry the Platypus!\n\nSeason 1 Episode 1 Rollercoaster / Candace Loses Her Head\nPhineas and Ferb build the coolest rollercoaster ever in their backyard! On Candace\'s birthday, the family takes a trip to Mount Rushmore.\n\nSeason 1 Episode 2 The Fast and the Phineas / Lawn Gnome Beach Party of Terror!\nThe boys convert Mom\'s car into a giant remote-controlled car and enter it in a race! The boys decide to make a tropical beach paradise in their very own backyard.\n\nSeason 1 Episode 3 The Magnificent Few / S\'winter\nPhineas and Ferb become real cowboys as they wrangle a stampede of cattle through Danville\'s city streets. It\'s wintertime in the summertime!\n\nSeason 1 Episode 4 Are You My Mummy? / Flop Starz\nPhineas and Ferb search for a mummy to call their own. Phineas and Ferb conspire to become one hit wonders.\n\nSeason 1 Episode 5 Raging Bully / Lights, Candace, Action!\nPhineas is challenged by Buford, the local bully, to an all out thumb war. Candace\'s dreams of glamour turn into monstrous nightmares.\n\nSeason 1 Episode 6 Get That Bigfoot Outa My Face! / Tree To Get Ready\nPhineas and Ferb organize a full day of summer camp activities! Phineas and Ferb decide to build the ultimate tree house.\n\nSeason 1 Episode 7 It\'s About Time! \nPhineas and Ferb find a time machine!\n\nSeason 1 Episode 8 Jerk De Soleil / Toy to the World\nPhineas and Ferb get everyone together and put on their own circus! The boys invent a toy that becomes the most popular toy in the world.\n\nSeason 1 Episode 9 One Good Scare Ought To Do It!\nIsabella is inflicted with an extreme case of hiccups!\n\nSeason 1 Episode 10 Hard Day\'s Knight, A / I, Brobot\nCandace gets stuck in a suit of armor and is mistaken for the Black Knight. The boys create an army of robots to get all their projects done.\n\nSeason 1 Episode 11 Mom\'s Birthday Episode / Journey to the Center of Candace\nPhineas and Ferb go out of their way to give mom the best birthday ever. The boys build a shrinking submarine and end up in Candace\'s stomach!\n\nSeason 1 Episode 12 Run Away Runway / I Scream, You Scream\nPhineas and Ferb create a clothing line that completely personifies summer. The boys make Isabella the world\'s biggest ice cream sundae.\n\nSeason 1 Episode 13 It\'s a Mud, Mud, Mud, Mud World / The Ballad of Badbeard\nThe boys create a super safe car for Candace so she can learn to drive. The kids set out on an open seas adventure.\n\nSeason 1 Episode 14 Dude, We\'re Getting the Band Back Together \nPhineas and Ferb put a big stadium concert together for Dad.\n\nSeason 1 Episode 15 Ready for the Bettys / The Flying Fishmonger\nPhineas and Ferb accidentally stumble upon Agent P\'s secret lair! The boys help their grandfather relive his glory days as a daredevil.\n\nSeason 1 Episode 16 Phineas and Ferb Get Busted\nThe boys get shipped off to military school.\n\nSeason 1 Episode 17 Greece Lightning / Leave the Busting to Us!\nThe boys recreate a chariot race after learning about ancient Greece at the museum. For once Candace has someone on her side - a reality show to help her bust her brothers.\n\nSeason 1 Episode 18 Crack That Whip / The Best Lazy Day Ever\nPhineas and Ferb set up a roller derby rink so Grandma Betty Jo can skate against her arch rival! It\'s such a nice day that Phineas and Ferb have decided to do nothing.\n\nSeason 1 Episode 19 Boyfriend From 27,000 B.C. / Voyage to the Bottom of Buford\nPhineas and Ferb discover a caveman who falls for Candace! After Buford loses his goldfish, Phineas and Ferb help him search for it.\n\nSeason 1 Episode 20 Put that Putter Away / Does This Duckbill Make Me Look Fat?\nWhile Candace is sick in bed, she asks Stacy to cover for her and monitor Phineas and Ferb. When the boys invent a body transporter, it actually works...on Candace and Perry.\n\nSeason  ...
#   'published_at': '2024-10-18T18:01:23Z',
#   'channel_title': 'Disney XD',
#   'tags': 'phineas and ferb, phineas and ferb full episode, phinease and ferb full episodes, phineas, ferb, doof, dr doof, candace, perry, doofenshmirtz, agent p, perry the platypus, phineas and ferb full episodes, disney xd full episodes, phineas and ferb doofenshmirtz, phineas and ferb episodes, ferb and phineas, disney xd phineas and ferb, ferb and phineas full episodes, phineas and ferb season 1, phineas and ferb in english, phineas & ferb, phineas and ferb season 1 livestream',
#   'category_id': '1',
#   'duration': 'P0D',
#   'view_count': '3093875',
#   'like_count': '12192',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'PLboHklFv2w',
#   'title': 'The doctor is caught in the classic dilemma again #movie #doctorwho #shorts #fantasy',
#   'description': '',
#   'published_at': '2024-12-12T14:09:00Z',
#   'channel_title': 'Brought Kooky',
#   'tags': '',
#   'category_id': '1',
#   'duration': 'PT59S',
#   'view_count': '108933',
#   'like_count': '9544',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': "I'm not stupid mate you've just played your last card bracewell is a bomb you're laughing deception second nature to there isn't a sincere bone in your body there isn't a bone in your body his power is derived from an oblivion pum call off your attack or we will detate the Android h no this is my best chance for the last of the darkness I can read the whole universe of you once and for all it but we will shatter the planet below the Earth will die screaming and if I let you go you'll be stronger than ever a new race of Darlings then choose doctor destroy the DXs or save the earth begin countdown of Oblivion continuum"},
#  {'video_id': '1wtNByFd_3s',
#   'title': 'Saps At Sea Trailer',
#   'description': 'Oliver suffers a nervous breakdown as a result of working in a horn factory, but when he follows doctor\'s orders about sea air, he finds an ex-con is aboard.\n\n-~-~~-~~~-~~-~-\nPlease watch: "An American in Berlin? - Oliver Hardy ~ with Philip Hutchinson" \n➨ https://www.youtube.com/watch?v=Joj2rg0j4n8\n-~-~~-~~~-~~-~- Donate for our restoration project of historic material: http://www.leetchi.com/c/pool-von-interpathe-16620838',
#   'published_at': '2014-04-14T14:38:00Z',
#   'channel_title': 'Inter-Pathé',
#   'tags': 'Dick und Doof, Laurel & Hardy, Saps At Sea (Film), Inter-Pathé, Brats, United States of America, Werner Schwier, Stan und Ollie, legal movies, Saps at Sea, free movies',
#   'category_id': '1',
#   'duration': 'PT2M',
#   'view_count': '2829',
#   'like_count': '10',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "all over me don't you realize the effect the sound of a horn has on me it makes me fighting mad in fact it gives me the ice to kill are you gonna stand for that no no no no no no no no that horn stand what's that it's my own intention the lung tester yes thank you"},
#  {'video_id': 'N4UpQBoE9Ak',
#   'title': 'PA mistakes real cop as an extra! | #TheRookie',
#   'description': "🎥 The Rookie (2018)\nSeason 2, Episode 9\n— ©️ ABC\n\n🎬 Subscribe for more clips! 🎬\n\n#police #tv #scene #clips #clip #shorts #nathanfillion #angelalopez #funny\n\n-\n\nThe Rookie is an American police procedural television series created by Alexi Hawley for ABC. The series follows John Nolan, a man in his forties, who becomes the oldest rookie at the Los Angeles Police Department (LAPD). The series is produced by ABC Signature and Lionsgate Television; it is based on real-life LAPD officer William Norcross, who moved to Los Angeles in 2015 and joined the department in his mid-40s.\n\nThe series stars Nathan Fillion (John Nolan), Alyssa Diaz (Angela Lopez), Richard T. Jones (Wade Grey), Titus Makin Jr. (Jackson West), Mercedes Mason (Zoe Andersen), Melissa O'Neil (Lucy Chen), Afton Williamson (Talia Bishop), Eric Winter (Tim Bradford), Mekia Cox (Nyla Harper), Shawn Ashmore (Wesley Evers), Jenna Dewan (Bailey Nune), Tru Valentino (Aaron Thorsen), and Lisseth Chavez (Celina Juarez). The Rookie premiered on October 16, 2018.",
#   'published_at': '2024-12-10T14:01:03Z',
#   'channel_title': 'The Rookie (Fan Page)',
#   'tags': '',
#   'category_id': '1',
#   'duration': 'PT14S',
#   'view_count': '2222054',
#   'like_count': '138899',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "sorry this this food isn't for background what uh extras eat someplace else or or you can he I mean any anywhere"},
#  {'video_id': 'XviHNdfuB9Y',
#   'title': '🎥 THREE BILLBOARDS OUTSIDE EBBONG, MISSOURI (2017) | Full Movie Trailer in Full HD | 1080p',
#   'description': "A mother personally challenges the local authorities to solve her daughter's murder when they fail to catch the culprit.\n----------------\nCast: Frances McDormand, Woody Harrelson, Sam Rockwell #TrailerCity #movie #trailer",
#   'published_at': '2018-02-19T14:00:02Z',
#   'channel_title': 'TRAILER CITY',
#   'tags': 'trailer, full movie trailer, new trailer, trailer 2017, best trailer, official trailer, movie trailer, official teaser, teaser, movie teaser, movie trailer 2017, cinema trailer, official preview, movie announced, three billboards outside ebbong missouri, three billboards, woody harrelson, sam rockwell, frances mcdormand, three billboards movie, three billboards trailer, billboards outside ebbong missouri, outside ebbong missouri, missouri movie, billboards outside',
#   'category_id': '1',
#   'duration': 'PT1M29S',
#   'view_count': '82429',
#   'like_count': '224',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "anyway trying to make me believe in reincarnation marnya because you're pretty but you ain't her [Music] she got killed still no arrests how come I wonder cuz there ain't no God in the whole world's empty and it doesn't matter what we do to each other I hope not I don't know what the police are doing I hadn't heard a word from them and said goddamn - I'll tell you this I've heard an awful lot for them since I put them billboards up [Music] or you keep a case in the public eye the better your chances are getting it solved and take me down arrest me they've got nothing to arrest you for oh yeah you ain't if I had some food I'd give it to you well I got us some Doritos they might kill you they're kind of pointy then where would we be [Music] [Music] [Music]"},
#  {'video_id': 'BNS6WOMs_5s',
#   'title': 'Nissan’s commitment to enriching people’s lives',
#   'description': '(Click the "CC" button in the right-hand lower corner of the video to switch on closed captions in English) \n\nCompanies like Nissan Motor Corporation exist to satisfy and bring value to individuals and communities. Our corporate purpose, “Driving innovation to enrich people’s lives” is our reason to be and at the core of everything we do. It’s a philosophy that unites us and a direction we strive towards. \n\nIt forms the foundation of our long-term vision, Nissan Ambition 2030, to empower journeys and society. The video shows the different functions and areas of the company, and the diverse employees that make up the driving force behind the products and technologies we provide. We dare to do what others don’t and will continue to support efforts towards a more sustainable and inclusive world. \n\nLearn more here: https://www.nissan-global.com/EN/SUSTAINABILITY/\n\nNissan Global YouTube Channel: The Nissan worldwide channel is our virtual showroom, showcasing our newest models, heritage vehicles, NISMO sports news and tech advancements. Subscribe to stay up-to-date on Innovation that Excites. Nissan is a global full-line vehicle manufacturer that sells more than 60 models under the Nissan and INFINITI brands. Nissan’s global headquarters in Yokohama, Japan, manages operations in six regions: Asia & Oceania; Africa, the Middle East & India; China; Europe; Latin America; and North America. \n\nChannel Link: https://www.youtube.com/nissan \nSubscribe: https://www.youtube.com/c/nissan?sub_confirmation=1\nConnect with us at: \nFacebook: https://www.facebook.com/nissan \nTwitter: https://twitter.com/nissan, https://twitter.com/nissanmotor \nInstagram: https://www.instagram.com/nissan/ \nLinkedin: https://www.linkedin.com/company/nissan-motor-corporation/',
#   'published_at': '2022-08-01T00:00:03Z',
#   'channel_title': 'Nissan',
#   'tags': 'Nissan, Nissan Motor, Nissan Intelligent Mobility',
#   'category_id': '2',
#   'duration': 'PT2M43S',
#   'view_count': '183529',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "As we look for new and exciting ways\nto keep the world moving in the future the endless possibilities for innovation\nand change are so amazing they are difficult to predict or imagine But what we do know is that the things that are important\nto us now, will remain exactly the same being close to the people we care about At Nissan Motor Corporation we are passionate about making innovations\nthat help you do just that As technology\nbecomes a bigger part of our lives it should be making your everyday easier helping us stay connected with each other We have always believed\nin human centric innovation that brings you closer to the people\nand passions you care about We are empowering journeys and societies making them safer cleaner and more inclusive Toward a future with zero\nemissions and zero fatalities Because we believe in driving innovations\nthat enrich people's lives From the newest employee,\nto the most experienced we push boundaries and challenge\nperceptions to keep innovating to work with our partners\nto shape a truly sustainable smart, and electrified future It's a journey we take together To a future\nfilled with excitement and hope"},
#  {'video_id': 'XrZZqUWYv7w',
#   'title': "How to check your car's tyre tread – expert advice from the RAC",
#   'description': "RAC patrol Ben shows you how to properly check your car's tyre tread.\n\nFor breakdown cover visit https://www.rac.co.uk/breakdown-cover\nTo find a garage near you visit https://www.rac.co.uk/approvedgarages/\nFor more driving advice visit https://www.rac.co.uk/drive/\nFor more car maintenance visit https://www.rac.co.uk/drive/advice/car-maintenance/\nFor everything else visit https://www.rac.co.uk",
#   'published_at': '2020-08-20T15:15:33Z',
#   'channel_title': 'RAC',
#   'tags': 'breakdown, breakdown cover, car maintenance',
#   'category_id': '2',
#   'duration': 'PT47S',
#   'view_count': '264203',
#   'like_count': '338',
#   'dislike_count': 0,
#   'default_audio_language': 'en-GB',
#   'transcript': "Here's how to check your car's tyre tread.\xa0\xa0 The minimum legal tyre tread depth for cars is\xa0\n1.6 millimetres, but safety experts recommend a\xa0\xa0 minimum of three millimetres. To check your\xa0\ntyre tread you can use a tyre tread gauge\xa0\xa0 but a 20 pence piece will also do the job as the\xa0\nouter edge of the coin is about two millimetres.\xa0\xa0 Insert the coin into the tread grooves across\xa0\nthe central three quarters of the tyre.\xa0\xa0 If you can't see the outer ring of the coin your\xa0\ntyres are above the minimum 1.6 millimetre limit,\xa0\xa0 but if you can see the outer ring\xa0\nyour tyres need replacing right away.\xa0\xa0 We suggest checking your tyre\xa0\ntread every couple of months or so\xa0\xa0 to make sure you have enough grip on\xa0\nthe road. Expert advice from the RAC."},
#  {'video_id': 'qk_dpv_a5RE',
#   'title': 'Ford BlueCruise Hands-Free Highway Driving for F-150® | Ford How-To | Ford',
#   'description': "Find out about available Ford BlueCruise* — hands-free highway driving technology available for the Ford F-150.\n\n*Driver-assist features are supplemental and do not replace the driver’s attention, judgment and need to control the vehicle. Ford BlueCruise is a hands-free highway driving feature. Only remove hands from the steering wheel when in a Hands-Free Blue Zone. Always watch the road and be prepared to resume control of the vehicle. It does not replace safe driving. See Owner's Manual for detail and limitations. Available on select vehicle models. The BlueCruise Prep Kit contains the hardware required for this feature. Requires purchased three-year connected service plan with regular map updates, FordPass™ App and modem activation. BlueCruise functionality expected third quarter 2021CY. Three-year Connected Service term with regular map updates begin on service start date. To continue service, a new connected service plan must be purchased. Plans are subject to change. See your Ford Account for terms and details. Service and features depend on compatible AT&T network availability. Evolving technology/cellular networks/vehicle capability may limit functionality and prevent operation of connected features. Failure to regularly update could result in BlueCruise being unavailable.\n\nLearn more about Ford support here: https://ford.to/36tjcC2\n\nDiscover more How-To videos here: https://ford.to/39rM8ao\n\nSUBSCRIBE: http://ford.to/SubscribeFordMotorCompany\n \n#Ford #F150\n\nConnect with Ford: http://ford.to/FordMotorCompany\nFacebook: http://ford.to/FordMotorCompanyFB\nTwitter: http://ford.to/FordMotorCompanyTW\nInstagram: http://ford.to/FordMotorCompanyIG\n\nAbout Ford:\nThe official YouTube channel for Ford Motor Company. Subscribe for weekly videos showcasing our vehicles, innovation and stories that inspire you to go further. Our videos are here for your entertainment, and you are welcome to use, share and embed links for all our videos, but the videos themselves are property of Ford Motor Company. You are not permitted to download any video and re-upload under any circumstances without written consent from Ford Motor Company.\n\nFord BlueCruise Hands-Free Highway Driving for F-150® | Ford How-To | Ford \nhttps://www.youtube.com/user/Ford",
#   'published_at': '2022-03-18T13:59:46Z',
#   'channel_title': 'Ford Motor Company',
#   'tags': 'F-150, active drive assist, bluecruise, blue cruise, hands-free driving, hands free blue zones, intelligent adaptive cruise control, driver facing camera, prep kit, Ford BlueCruise, hands-free highway driving, Ford hands-free driving, Ford F-150, 2021 F-150, 2022 F-150, Ford features, Ford how to, Ford how to guide, Ford, Ford Motor Company, Hands- free highway driving',
#   'category_id': '2',
#   'duration': 'PT4M30S',
#   'view_count': '185379',
#   'like_count': '1883',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': "(upbeat music) - [Narrator] Did you know that your F-150 can be equipped with an available feature called Ford BlueCruise\nhands-free highway driving? This technology adds\nhands-free highway driving when using available intelligent\nAdaptive Cruise Control with Stop-and-Go, Lane Centering, and Speed Sign Recognition. Ford BlueCruise is available\non specific sections of divided highways called\nHands-Free Blue Zones that make up over 100,000\nmiles of North American roads. Here's how it works. (upbeat music) Ford BlueCruise allows you to take your hands off the steering wheel while the system accelerates, brakes, and steers your F-150 within the lane. It uses advanced infrared\ndriver-facing cameras that are located on the A-pillar\nand above the SYNC screen to track eye gaze and head position to ensure that you're\npaying attention to the road while in Hands-Free mode, as well as hands-on Lane Centering mode, which works on most roads\nwith visible lane lines. A few things need to happen\nbefore it can be activated. Ford BlueCruise must be enabled, Adaptive Cruise Control must be turned on, the system must be able to\ndetect both lane markings, your hands must initially\nbe on the steering wheel, and your eyes need to be\nfocused on the road ahead at all times. To enable Ford BlueCruise, go to Features, press Driver Assistance, press Cruise Control,\nthen press Lane Centering. To turn Ford BlueCruise and\nAdaptive Cruise Control on, use this button on the steering wheel. Press the plus and minus\nbuttons to adjust your speed. If you wish, this button can\nbe used to select the gap between your vehicle and\nthe vehicle ahead of you. Once the system is on, the\ncolor of this indicator changes to let you know the status. Blue means that Ford BlueCruise is on and your in Hands-Free mode. If the system determines that you are not looking at the road, you will either get a message displayed in the instrument cluster, or you may also hear a chime to remind you to return your eyes to the road. The warning you will get depends on where the vehicle determines\nyour eyes are looking. If you do not react to the warnings, Ford BlueCruise cancels, quickly activates and releases the brakes, and slows your vehicle down while maintaining steering control. (upbeat music) On roadways where hands-free\ndriving is not permitted, the system can still accelerate, brake, and steer the vehicle in the lane if the driver hands are on the wheel and if both lane markings can be detected with Lane Centering mode. When this indicator is green, that means that Ford BlueCruise is active for hands-on driving. When this is present, you must keep your hands\non the steering wheel. If you need to return\nyour attention to the road or resume control of the vehicle, a prompt in the instrument\ncluster will notify you. To turn Ford BlueCruise off, press either the cancel/resume button or the Adaptive Cruise Control button or switch your vehicle off. Keep in mind, some external conditions may cancel Ford BlueCruise. For example, if lane\nmarkings are not available or not visible by the vehicle's camera or the lane becomes too narrow. If this occurs while your\nhands are on the steering wheel and your eyes are on the\nroad, a tone will sound and a message will appear in the instrument cluster alerting you that Ford BlueCruise has been canceled. However, if this occurs while\nyou're not focused on the road and your hands are not\non the steering wheel, the system will display a message and a tone will sound\nuntil you resume control. If you do not resume control in time, Ford BlueCruise quickly\nactivates and releases the brakes and slows your vehicle down while maintaining steering control. When you take control and again, a message will prompt you to\npress the accelerator pedal to allow the system to resume. Keep in mind that heavy\nrainstorms, snowstorms, or fog may make it difficult for\nthe system to operate, especially if the camera or\nother  ...
#  {'video_id': 'bG8Vxdm9VWw',
#   'title': '2010 FJ Cruiser How-To: Automatic Transmission And Drive System | Toyota',
#   'description': "When the going gets rough, count on your FJ's transmission and transfer case to pull through. Options shown. Not all features available on all vehicles and model grades. Please see your Owner's Manual for further details and important safety information. Toyota USA\n\nSUBSCRIBE: http://bit.ly/ToyotaSubscribe\n\nAbout Toyota:\nWe’re in the business of making great cars and trucks. But we also work every day to apply and share our know-how in ways that benefit people, the community and our planet in order to build a better tomorrow. We’ve been a part of life in America for over 50 years. And while we’re passionate about making great cars and trucks, our story is about much more than our vehicles. \n\nConnect with Toyota USA online:\nVisit the Toyota WEBSITE: http://bit.ly/ToyotaSite\nLike Toyota on FACEBOOK: http://bit.ly/ToyotaUSAFB\nFollow Toyota on TWITTER: http://bit.ly/ToyotaTwitter\nFollow Toyota on INSTAGRAM: http://bit.ly/ToyotaInsta\n+1 Toyota on GOOGLE+:\xa0http://bit.ly/ToyotaUSAGplus\n\nFJ Cruiser How-To: Automatic Transmission And Drive System | 2010 FJ Cruiser | Toyota\nhttp://www.youtube.com/user/ToyotaUSA",
#   'published_at': '2011-10-11T02:46:17Z',
#   'channel_title': 'Toyota USA',
#   'tags': "FJ Cruiser, 2010, Basic Operations, toyota, owners, how-to, videos, transmission, speed, 4wd, sequential, shift, 2010_fj_cruiser, Toyota, Toyotathon, ToyotaUSA, Let's Go Places, Entune, Car, Automobile, Vehicle, new toyota models, corolla, camry, yaris, avalon, sienna, tacoma, tundra, rav4, highlander, 4Runner, land cruiser, sequoia, FJ cruiser, venza, hybrid, electric car, prius",
#   'category_id': '2',
#   'duration': 'PT2M19S',
#   'view_count': '281872',
#   'like_count': '1260',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': "(upbeat music) - [Narrator] Automatic transmission. The automatic transmission available on the FJ Cruiser gives the\ndriver a range of choices. Shifting the lever to D for\ndrive will accommodate most on road driving needs. To slow the vehicle when\ndescending a steep grade, the driver can shift the transmission into fourth gear by pushing\nthe lever to the left. If more engine braking is needed, the lever can be pulled\nback into third gear. To switch from third gear to second, push the lever to the right and down, then to the right for low or first gear. On FJ Cruisers with four-wheel drive, it's best to leave the smaller\nlever in the H2 position, that's high speed two-wheel\ndrive for most on road driving. When the vehicle loses\npower due to wheel slipping, the driver can shift into high speed, four wheel drive or H4 without stopping. Begin by slowing down to\nless than 50 miles per hour, then pull the smaller lever\nback into the H4 position, a four-wheel drive icon will appear in the instrument cluster. When off-roading in rugged\nterrain, sand or mud, the driver can select low\nspeed four-wheel drive or L4. To engage low speed four-wheel drive, stop the vehicle and depress the brake, put the automatic\ntransmission into neutral, shift the smaller lever\npast neutral to L4, the VSC off indicator will light up, then put the automatic\ntransmission back into drive. To return to high four-wheel\ndrive or two-wheel drive, stop the vehicle and\nfollow the same process. Note, a vehicle should be driven in four-wheel drive for at\nleast 10 miles each month to keep all the components lubricated. If your vehicle doesn't shift as expected, refer to the owner's manual."},
#  {'video_id': 'BIodjkYabxU',
#   'title': 'Ford Bronco™ Sport 4x4 Traction Systems | Ford How-To | Ford',
#   'description': 'Learn about G.O.A.T. Modes™ (Goes Over Any Type of Terrain) and other traction control systems in your Bronco Sport SUV that help enhance your off-road experiences.*\n\n*Always consult the owner’s manual before off-road driving, know your terrain and trail difficulty and use appropriate safety gear.\n\nFord is committed to the preservation of the environment and treading lightly. Learn about the Ford Bronco Wild Fund: http://ford.to/2OT5Mqx\n\nLearn more about Ford owner here: https://ford.to/2Y3I2kP\n\nDiscover more How-To videos here: https://ford.to/39rM8ao \n    \nSUBSCRIBE: http://ford.to/SubscribeFordMotorCompany\n\n#Ford \n\nConnect with Ford: http://ford.to/FordMotorCompany \nFacebook: http://ford.to/FordMotorCompanyFB \nTwitter: http://ford.to/FordMotorCompanyTW \nInstagram: http://ford.to/FordMotorCompanyIG \n\nAbout Ford:\nThe official YouTube channel for Ford Motor Company. Subscribe for weekly videos showcasing our vehicles, innovation and stories that inspire you to go further. Our videos are here for your entertainment, and you are welcome to use, share and embed links for all our videos, but the videos themselves are property of Ford Motor Company. You are not permitted to download any video and re-upload under any circumstances without written consent from Ford Motor Company.\n \nFord Bronco™ Sport 4x4 Traction Systems | Ford How-To | Ford\nhttps://www.youtube.com/user/Ford',
#   'published_at': '2021-01-25T13:59:54Z',
#   'channel_title': 'Ford Motor Company',
#   'tags': 'Ford How-To, how to videos, how to, Ford features, new features, G.O.A.T. modes, normal, Eco mode, Sport mode, Rear Differential Lock, Mud/Ruts Mode, Sand, Rock Crawl, four-wheel drive lock, Traction Control System, Trail Control, Ford how to guide, Ford how to, Ford, Ford Motor Company',
#   'category_id': '2',
#   'duration': 'PT3M19S',
#   'view_count': '106592',
#   'like_count': '630',
#   'dislike_count': 0,
#   'default_audio_language': 'en-US',
#   'transcript': '(light music) - [Narrator] Your Bronco\nSport is built to handle your adventures. Let me show you. The controls on your center console will help customize your\noff-road experiences. First, let\'s talk about G.O.A.T. Modes, which stands for "goes\nover any type of terrain." Turn the G.O.A.T. Modes dial\nleft or right to switch modes. Normal Mode is for everyday driving, and provides a balance\nof excitement, comfort, and convenience. Next up Eco Mode is designed\nto help reduce fuel consumption and deliver maximum efficiency. For a sporty steering\nfield choose Sport Mode. You\'ll experience increased\naccelerator pedal response as the powertrain system pulls\nonto the lower gears longer helping your vehicle accelerate faster. Slippery Mode helps make your\nBronco Sport easier to control on slippery surfaces, like\nice and snow covered roads. Traction and stability\ncontrols are more restrictive in this mode for better\nhandling and control. Mud/Ruts Mode is only\nfor off-road driving. This mode gives you the optimum experience when traversing muddy,\nrutted, or uneven terrains. The traction and stability\ncontrols are less restrictive to allow more tire spin and\nclear mud from the tires. Sand Mode is also for off-road use only. Use this for fun driving\nin soft, dry sand. Rock Crawl Mode is for\noff-road use at very low speed, when navigating aggressive uneven terrain that may include large rocks. Back to the center console. This button turns on\nfour wheel drive lock. Turning this on increases\nfour wheel drive performance by preventing the front and\nrear axles from disconnecting. Certain G.O.A.T. Modes will engage four wheel drive lock automatically. This button turns on the Rear\nDifferential Lock feature, which provides additional\ntraction when driving over aggressive terrain, or in case your Bronco Sport gets stuck. Rear Differential Lock\nwill engage automatically in certain drive modes. Now let\'s talk about the\ntraction control system, which turns on automatically each time you start your vehicle. If your Bronco Sport\nexperiences excessive wheel spin and a loss of traction, the traction control\nsystem applies the brakes to individual wheels, and when needed, simultaneously reduces engine power. This will result in the\nvehicle accelerating through slippery or loose surfaces. You can press this button if\nyou prefer to limit traction and stability control interference. You may need to do so when\nnavigating a steep incline so that your vehicle has\nthe necessary engine power. And finally, this button\nis for trail control, which is for off-road\ndriving at low speed. This system automatically\ncontrols engine torque and vehicle braking to\nmaintain a vehicle speed that you select so that\nyou can focus on steering. It\'s like cruise control\nfor off-road driving. You can set your speed between\none and 20 miles per hour when moving forward, and one to six miles per hour in reverse. Use the controls on your steering wheel to set your preferred speeds. Any questions? Go to Owner.Ford.com.'},
#  {'video_id': 'paV0NdirSnM',
#   'title': 'Mahir & Doruk 😗🔥',
#   'description': '#kardeşlerim #kardeslerim #birgecemasalı #canfeza #asiyeeren #suburcuyazgıcoşkun #dorukatakul #onurseyityaran #burakdeniz #asdor #mahcan #formyfamily #مسلسلات_تركية #اخوتي #مسلسل_تركي #explore #yalılerim #viralshort #short #fyp #shorts',
#   'published_at': '2024-12-10T16:00:44Z',
#   'channel_title': 'Yalı LERİM',
#   'tags': '',
#   'category_id': '10',
#   'duration': 'PT16S',
#   'view_count': '328722',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'pfiCNAc2AgU',
#   'title': 'christmas lofi radio 🎄cozy beats to get festive to',
#   'description': '🎼 | Listen on Spotify, Apple music and more\n→  https://fanlink.tv/LofiGirl-Christmas-2024\n\n🌎 | Lofi Girl on all social media\n→  https://fanlink.tv/lofigirl-social\n\n👕 | Lofi Girl merch\n→  https://bit.ly/Iofigirl-shop\n\n🎭 | Create your lofi avatar now\n→  https://lofigirl.com/generator/\n\n💬 | Join the Lofi Girl community\n→   https://bit.ly/lofigirl-discord\n→   https://bit.ly/lofigirl-reddit\n\n🎨 | Art by Lofi Studio (full list of artists here)\n→  https://www.instagram.com/p/CuChqFXs08M/\n\n🧡All visuals and music in this video are 100% crafted by talented human artists, without the use of AI. We’re committed to delivering genuine, hand-made creations for our audience to enjoy.',
#   'published_at': '2024-11-04T16:47:20Z',
#   'channel_title': 'Lofi Girl',
#   'tags': 'chilledcow, chilled cow, lofi, lofi hiphop, lofi hip hop, lo-fi hiphop, lo fi hip-hop, lofigirl, lofi girl, relaxing beats, beats, chill beats, halloween, scary music, spooky music, halloween radio, halloween music, halloween live, halloween playlist, halloween lofi, lofi halloween',
#   'category_id': '10',
#   'duration': 'P0D',
#   'view_count': '4716595',
#   'like_count': '46947',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'pRGeYjd0-qM',
#   'title': 'Beautiful Relaxing Hymns, Peaceful Instrumental Music, "The Bells of Peace" by Tim Janis',
#   'description': 'Beautiful Relaxing Hymns, Peaceful Instrumental Music, "The Bells of Peace" by Tim Janis.  Traditional Hymns like, Holy Holy Holy, Amazing Grace, Ave Maria, How Great Thou Art, Blessed Assurance, Be Thou My Vision, It is Well, Great is Thy Faithfulness, Praise to the Lord The Almighty, What a friend I have in Jesus and more. My instrumental music can help you find deep relaxation, relieve anxiety, and find peace. My music incorporates relaxing sounds of nature and features flute music, piano music, harp music, & violin music.\nI am a composer from Maine and created my channel as a place to visit, relax, and find peace. \n\nDeep in the heart of the snow filled woods the wildlife of the winter enjoy\'s it\'s peace and solitude, come enter into this beauty all while we listen to our favorite hymns played on piano. We are so happy you are here with us :)  Peace and blessings Tim & Elizabeth, Reno, Bella and Roo Roo \n\nJoin Elizabeth and I on AMAZING adventures :) \nhttps://youtu.be/8X1qVwBIIVM?si=jF5Ai7j1TDitCJnA\n\nEnjoy our videos in 4k -  click here. \nhttps://youtu.be/Rs3-OJBYKSY \n\nPeaceful Winter Sunrise soothing Hymns \nAll arrangments by Tim Janis \nMusic information:\nComposer: Tim Janis \nCopyright:  Tim Janis Ensemble Inc.',
#   'published_at': '2024-12-07T02:38:24Z',
#   'channel_title': 'Tim Janis',
#   'tags': 'Hymns, Traditional Hymns, Amazing Grace, Peaceful music, Prayer and meditation, Tim Janis',
#   'category_id': '10',
#   'duration': 'P0D',
#   'view_count': '85176',
#   'like_count': '1549',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'JKGPjoJBd3o',
#   'title': "♫ FULL TUTORIAL: GOD'S UP TO SOMETHING GOOD by Hart Ramsey (easy gospel piano tutorial lesson) ♫",
#   'description': 'http://www.PianoClubhouse.com This is a tutorial/how to play "GOD\'S UP TO SOMETHING GOOD", by Hart Ramsey & The NCC Family Choir. For access to more full-length tutorials, visit PianoClubhouse.com.',
#   'published_at': '2012-11-22T03:00:23Z',
#   'channel_title': 'PianoClubHouse',
#   'tags': 'live, concert, american, idol, fox, songs, chords, piano, keyboard, how, play, lesson, teach, tutorial, free, solo, howto, instrumental, help, cover, easy, How-to, gods up to something good, god is up to something good, gospel, Gospel Music (Musical Genre)',
#   'category_id': '10',
#   'duration': 'PT12M19S',
#   'view_count': 0,
#   'like_count': '2',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'XszsV5rx4Xo',
#   'title': 'Soft Jazz Music On A Peaceful Winter Day ❄Fireplace Crackling And Fire Sounds To Relax',
#   'description': 'Soft Jazz Music On A Peaceful Winter Day ❄Fireplace Crackling And Fire Sounds To Relax\nSoft Jazz Music On A Peaceful Winter Day ❄Fireplace Crackling And Fire Sounds To Relax\nSoft Jazz Music On A Peaceful Winter Day ❄Fireplace Crackling And Fire Sounds To Relax\n\n=======================\n\nCozy Jazz House offers audio and visual experiences that help you sleep better, focus deeper, and relax your mind. From stunning natural landscapes to magical coziness, our videos take you to creative locations to stimulate your senses and calm your mind. We believe that listening to relaxing white noise and nature sounds is an effective way to reduce stress and anxiety, while promoting mindfulness and mental health.\n\nThis is a music video exclusively produced by our Company, It brings spiritual and humanistic values \u200b\u200bto the audience.\n\n🎬 Video editing software: Adobe Premiere Pro CC\n🎬 Video editing software: Adobe After Effects Pro CC\n📷 Photo editing software: Adobe Photoshop\nGmail: nghiaok303@gmail.com',
#   'published_at': '2024-11-20T07:05:20Z',
#   'channel_title': 'Cozy Jazz House',
#   'tags': 'Relaxing, Relaxation, Ambience, nature, asmr, ambiance, Sleep, Study, Meditation, Nature Sounds, calmed by nature, Relaxing Sounds, Relaxing Ambience, stress relief, sounds for sleep, relaxing nature, nature sounds, asmr ambience, sounds for studying, asmr rooms, ambient nature, ASMR Ambience, Rain Sounds, White Noise, relaxing music, cozy room, rain on window, rain and thunder sounds, rain on window with thunder, calm by natu, rerelaxing rain sounds for sleeping, Cozy Jazz House',
#   'category_id': '10',
#   'duration': 'P0D',
#   'view_count': '359721',
#   'like_count': '1605',
#   'dislike_count': 0,
#   'default_audio_language': 'vro',
#   'transcript': ''},
#  {'video_id': 'VH-7XjrBaB8',
#   'title': 'Axolotl Olympics',
#   'description': "I made an Axolotl Agiligy Course for my axolotl Lucy! This was a super fun temporary setup with Lucy's favorite snack as a reward at the end.\n\nI use Wetpets aquariums for all my builds. You can get yours here with $25 off using this link!: https://wetpets.co/\n\nYou can subscribe to my Patreon for exclusive behind-the-scenes content and early access to my video ideas and Wetpets product launches. Your support makes everything I do possible. Subscribe here: https://www.patreon.com/aquariuminfo\n\nIf you have any comments, suggestions or questions, leave them down in the comments! Also for additional content like this, video tutorials, projects sneak peeks and more, follow me on Facebook and Instagram @aquariuminfo.\n\n.\n.\n\nMusic:\nMonkeys Spinning Monkeys Kevin MacLeod (incompetech.com)\nLicensed under Creative Commons: By Attribution 3.0 License\nhttp://creativecommons.org/licenses/by/3.0/\n\n#aquariuminfo #aquacrew",
#   'published_at': '2021-09-20T16:40:09Z',
#   'channel_title': 'Aquarium Info',
#   'tags': 'axolotl, tiktok, minecraft, cute, how to, axolotl side of tiktok, axolotl minecraft, fish, tank, aquarium, build, axolotl minecraft tank, tame, pets, baby, big, rare, agility course, animals doing things, axolotls',
#   'category_id': '15',
#   'duration': 'PT3M3S',
#   'view_count': '1061213',
#   'like_count': '11227',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': "this is Lucy my axolotl and this is an axolotl\xa0\nagility course it's my attempt to get Lucy\xa0\xa0 moving while stimulating her brain activity she\xa0\nwill need a pass through what is basically a\xa0\xa0 three-part ninja warrior obstacle course and at\xa0\nthe end she will be rewarded with her favorite\xa0\xa0 snack an earthworm why did i choose an earthworm\xa0\nover the course of her lifetime i've had lucy a\xa0\xa0 variety of snacks she eats specially formulated\xa0\npellets daily blood worms every few days and\xa0\xa0 earthworms on special occasions earthworms\xa0\nhave quickly become her absolute favorite snack\xa0\xa0 this is a custom-made acrylic donut tank as\xa0\nyou can see there's a hollow core in the center\xa0\xa0 this will allow us to watch lucy as\xa0\nshe makes her way through the course\xa0\xa0 the first challenge is to glide through this\xa0\ntunnel the change in lighting should help to\xa0\xa0 stimulate lucy's brain and bring\xa0\nher one step closer to her snack\xa0\xa0 if you know lucy you know she loves a tunnel\xa0\nor cave i can't see this one posing any issues\xa0\xa0 for her i used a fish safe basket silicone\xa0\nand these slate rocks to piece it together\xa0\xa0 let's add it to our tank and continue laying\xa0\nthe course next up we have this rope ladder\xa0\xa0 now this may look easy but this ladder is quite\xa0\nbuoyant and will be a challenge to pass over\xa0\xa0 axolotls have an amazing sense of touch so these\xa0\nnatural dowels will help lucy on her ascent\xa0\xa0 lucy's balance will definitely be put to the test\xa0\nfinally we have the great wall of the lucky bamboo\xa0\xa0 i've used this plan with lucy before and she\xa0\nloves it i wonder if her familiarity with these\xa0\xa0 will help her during this challenge these stalks\xa0\nare in a linear formation and create a small\xa0\xa0 opening that lucy must get through to complete the\xa0\ncourse to lay the course i started with white sand\xa0\xa0 i love using white sand in my aquariums\xa0\nbecause it gives the tank a clean crisp look\xa0\xa0 did you know that axolotls are compatible with\xa0\nsand when they're longer than four inches they\xa0\xa0 can pass sand without impaction let's fill up\xa0\nthe tank and finish adding in our obstacles\xa0\xa0 these aquatic plants will give our agility course\xa0\na more natural look while also helping to filter\xa0\xa0 and remove nitrates from the water they will\xa0\nalso provide some coverage for lucy in the tank\xa0\xa0 this large piece of serious stone will act as\xa0\nour starting point for lucy we will place our\xa0\xa0 prize directly on the other side of this wall\xa0\nlet's add our filter before cycling the tank\xa0\xa0 this process typically takes between two to four\xa0\nweeks and helps to establish beneficial bacteria\xa0\xa0 i was able to speed up this process by using\xa0\nsome of lucy's established filter media\xa0\xa0 it's finally time to add lucy to the tank she's\xa0\nbeen patiently waiting to take on the course\xa0\xa0 look here she goes she's at the starting point\xa0\nand headed for the first obstacle as i expected\xa0\xa0 this one wasn't too difficult for her it's what's\xa0\nto come that will be the most challenging to help\xa0\xa0 motivate her for obstacle number two i placed\xa0\none of her pellets at the peak of the bridge she\xa0\xa0 made her way up the bridge and completely missed\xa0\nthe snack she's on her way to the final obstacle\xa0\xa0 it took her no time at all to squeeze\xa0\npast the great wall of the lucky bamboo\xa0\xa0 in the end i helped her out with\xa0\nher worm she worked so hard today\xa0\xa0 even though it took her three hours to complete\xa0\nthe course i'm so proud of her thanks for watching"},
#  {'video_id': 'h3qWScaLB9I',
#   'title': 'I Rescued an Axolotl',
#   'description': 'Kirby is a rescue axolotl that was surrendered to my local pet store 🥺. When I found him he was in super bad shape and I was unsure if he would make it through the first night. \n\nI wanted to make sure I did everything I could to give him a second chance and the best life possible. Kirby has a long way to go.  Be sure you are subscribed to the channel to follow his journey!\n\nI use Wetpets aquariums for all my builds. You can get yours here: https://wetpets.co/\n\nYou can subscribe to my Patreon for exclusive behind-the-scenes content and early access to my video ideas and Wetpets product launches. Your support makes everything I do possible. Subscribe here: https://www.patreon.com/aquariuminfo\n\nIf you have any comments, suggestions or questions, leave them down in the comments! Also for additional content like this, video tutorials, projects sneak peeks and more, follow me on Facebook and Instagram @aquariuminfo.',
#   'published_at': '2022-02-24T15:15:10Z',
#   'channel_title': 'Aquarium Info',
#   'tags': 'animal video, animals, animal rescue, cute animals, pets, wildlife, pet videos, wildlife videos, rescuing animals, axolotls, what are axolotls, axolotl explained, the dodo axolotl, amphibians, newt, salamander, axolotl care, aquariums, aquatics, aquarium info, rescue axolotl',
#   'category_id': '15',
#   'duration': 'PT3M6S',
#   'view_count': '6357562',
#   'like_count': '70924',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "this is kirby he has a rescue axolotl that is in really bad shape i'm going to attempt to nurse kirby back to health i made him this rehabilitation tank that has some amazing places for him to hide do you think that he's going to get better kirby is showing some serious signs of neglect when i heard that kirby was surrendered to the pet store i knew that i had to take him home just so i can show you how bad it is let's compare him to lucy my healthy axolotl lucy has all her fingers a strong tail and beautiful fluffy gills i really hope that i can get kirby looking like lucy again after a few days at home kirby still won't eat i have him in a quarantine tank and i'm administering a black tea bath daily to help him fight his fungal infection let's get back to setting up a new home i knew i had to create a cave for kirby since axolotls prefer dim lighting this will provide a place for him to hide as well as a place to sleep at night i used pvc piping and these river stones to create a more natural look since kirby is full grown sand is a great choice for his setup this is also known as substrate and is a great host for beneficial bacteria once we're ready we can add in our cave to our fish tank i always aim to replicate a natural environment so i added a few stones along the perimeter this is a peace lily since this plant can grow fully submerged in water it's the perfect choice for aquascaping first we'll need to clear the roots of any debris let's add our peace lily on top of our cave and secure it with a few pieces of river stone i can't wait to see kirby exploring the different tunnels of the cave we can't forget to add our aquatic plants to our setup adding live plants to an aquarium has many benefits it's time to spray it down this will help to prevent our plants from drying out while i prepare to fill up our fish tank let's use this tube to fill up our fish tank be sure the water isn't hitting the sand directly this helps make for a super clear fill don't forget to add in your filter before cycling your fish tank this is a critical step in keeping your fish safe did you know that axolotls require cooler water temperatures unlike other wet pets they will not need a heater they prefer water temperatures between 60 and 64 degrees fahrenheit if you live in a warmer climate you can purchase a chiller to cool the water temperature of your axolotl tank kirby is almost ready to go in let's acclimatize him by slowly adding a cup of tank water over the course of a half an hour look here he goes kirby is off and exploring his new tank let's give him a worm i'm so excited he's finally eating oh no he spit it back out on day two he found his cave at this point he was looking a lot better and almost all of the fungus had cleared up let's try feeding him mice's trim after waiting for what seemed like an eternity he finally had a tiny nimble and from there he was unstoppable he finally had his appetite back be sure to stay tuned for updates on his progress thanks for watching"},
#  {'video_id': 'gG_pxZDrFi0',
#   'title': 'I Built a Giant Shrimp Eco-sphere',
# ...
#  {'video_id': 'QeozWoGmsdw',
#   'title': '弟弟去世那天，村口的算命瞎子說我晦氣，爸爸一聽就把我扔進零下的水缸裏。就在我快要淹死的時候，寡婦姑媽出現了，救了我並帶我離開。全村人都笑話我們，但20年後，我們母女回鄉，讓所有人都大吃一驚。#為人',
#   'description': '弟弟去世那天，村口的算命瞎子說我晦氣，爸爸一聽就把我扔進零下的水缸裏。就在我快要淹死的時候，寡婦姑媽出現了，救了我並帶我離開。全村人都笑話我們，但20年後，我們母女回鄉，讓所有人都大吃一驚。#為人\n 弟弟去世那天，村口的算命瞎子說我晦氣，爸爸一聽就把我扔進零下的水缸裏。就在我快要淹死的時候，寡婦姑媽出現了，救了我並帶我離開。全村人都笑話我們，但20年後，我們母女回鄉，讓所有人都大吃一驚。#為人\n\n此頻道視頻由本人獨自完成，嚴禁一切盜用者，一旦發現將採取法律手段！ 歡迎收看【關於暖風故事匯】YouTube官方頻道。\n每個故事都是獨立的，所有影片都符合平臺合作規範和使用政策，不存在重複內容，故事中的人物均為化名。\n本頻道每天爲大家帶來家長里短的故事，傳遞積極正向的能量，讓您在千篇一律的生活中變得並不平淡。\n希望本頻道講述的故事能夠引發大家對生活分享，在評論區留下您所遇見的各種雞零狗碎的事情，悅讀人生、品位人生，家家都有本難練的經，願您的生活可以得償所願！\n如果您對本頻道的內容有感觸，請點贊、訂閱、分享，祝您身體安康、平安四季。\n\n幸福生活,家長裡短,故事朗讀,原創故事,成長,人生價值',
#   'published_at': '2024-08-12T10:00:33Z',
#   'channel_title': '關於暖風故事匯',
#   'tags': '幸福生活, 家長裡短, 故事朗讀, 原創故事, 成長, 人生價值',
#   'category_id': '37',
#   'duration': 'PT52M10S',
#   'view_count': '1',
#   'like_count': '0',
#   'dislike_count': 0,
#   'default_audio_language': 'zh',
#   'transcript': ''},
#  {'video_id': 'LoT-rqIeClE',
#   'title': 'Family Guy Funny Moments😂😂😂 #shorts',
#   'description': 'Family Guy Best Moments |Family Guy \nDaily Family Guy\nfamily guy #SHORTS\nfamily guy full\nfamily guy \nfamily guy full episode,family guy full hd\nfamily guy full episode nocuts\nfamily guy new episode\nfamily guy new season\nfamily guy season 20\nfamily guy season 20 full episode\nfamily guy full nocuts',
#   'published_at': '2022-03-28T17:23:52Z',
#   'channel_title': 'Natural Disasters',
#   'tags': 'short, shorts, familyguy, peter',
#   'category_id': '37',
#   'duration': 'PT56S',
#   'view_count': '1',
#   'like_count': '0',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "to have my ring it's one of my most important possessions and i want you to have it okay red flag red flag everybody [Music] hey stewie wanna go down the slide um what's the matter you never been down the slide before yeah like like a thousand times just done it so much i'm bored with it that's all all right i guess we're doing this whoa come on down stewie this is crazy this is crazy this is crazy all right you can do this stewie here we go are you okay yeah that wasn't so bad you might want to move that farting polish kid is coming down the slide ah"},
#  {'video_id': 'YJ6cFIZaaNE',
#   'title': 'Family Guy Funny Moments😂😂😂 #familyguy #comedy #funny #petergriffin',
#   'description': 'Family Guy Best Moments |Family Guy \nDaily Family Guy\nfamily guy #SHORTS\nfamily guy full\nfamily guy \nfamily guy full episode,family guy full hd\nfamily guy full episode nocuts\nfamily guy new episode\nfamily guy new season\nfamily guy season 20\nfamily guy season 20 full episode\nfamily guy full nocuts',
#   'published_at': '2022-03-27T19:23:54Z',
#   'channel_title': 'Natural Disasters',
#   'tags': 'short, shorts, familyguy, peter',
#   'category_id': '37',
#   'duration': 'PT1M',
#   'view_count': '14',
#   'like_count': '0',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "you well that would just leave england i'm a brave guy lois oh yeah i bet you're not brave enough to laugh at death watch me oh thanks like i don't have enough purple fitting it ew how did you do that oh well let's just say when i was younger i uh did some films i'm not particularly proud of well that does it for me could you tell me when you're leaving to go back in time i was talking to a robe on the coat rack for 20 minutes before i realized you weren't in it ah for god's sake leave me alone i'm working don't yell at your mother what the hell are you talking about animals fight all the time not with nuclear arms you can't hug your children with nuclear arms check blaze see this is why i hate clothes shopping i have no ass i minus an ass i gotta go i got tickets to celine dion i'm not gonna kill her i'm just gonna watch her die on her own anyone anyone"},
#  {'video_id': 'axk94ymUs74',
#   'title': 'Family Guy Funny Moments😂😂😂 #shorts',
#   'description': 'Family Guy Best Moments |Family Guy \nDaily Family Guy\nfamily guy #SHORTS\nfamily guy full\nfamily guy \nfamily guy full episode,family guy full hd\nfamily guy full episode nocuts\nfamily guy new episode\nfamily guy new season\nfamily guy season 20\nfamily guy season 20 full episode\nfamily guy full nocuts',
#   'published_at': '2022-03-29T18:58:58Z',
#   'channel_title': 'Natural Disasters',
#   'tags': 'short, shorts, familyguy, peter',
#   'category_id': '37',
#   'duration': 'PT26S',
#   'view_count': '5',
#   'like_count': '0',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': "well downward now you really are the big man of the house mother change him back you know and dora uh i'm getting a little sick of this crap you ever seen one of these huh you know what this is huh no yeah it's holy water huh yeah try it how's that feel huh you like that yeah power of christ compels you i hate bewitched hey so that's a pretty reasonable"},
#  {'video_id': 'hnlA1tsY-lI',
#   'title': 'falk1',
#   'description': 'falk1',
#   'published_at': '2008-12-18T19:08:31Z',
#   'channel_title': 'bigschmiech',
#   'tags': 'falk1',
#   'category_id': '39',
#   'duration': 'PT1M5S',
#   'view_count': '20612',
#   'like_count': '6',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'wk3pggOhHHA',
#   'title': 'bolide caught by taxi camera',
#   'description': 'Horror comet,bolide  caught by taxi camera',
#   'published_at': '2015-11-04T03:25:25Z',
#   'channel_title': 'Duy Khanh Le',
#   'tags': '',
#   'category_id': '39',
#   'duration': 'PT9S',
#   'view_count': '4517',
#   'like_count': '4',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': '1o-oWUCpTKQ',
#   'title': 'Re: Ghost Game',
#   'description': 'Video Cam Direct Upload',
#   'published_at': '2009-04-16T11:48:27Z',
#   'channel_title': 'vishalagni200',
#   'tags': 'Horror, Witches, Ghost, Game, mysterious, game, suspense',
#   'category_id': '41',
#   'duration': 'PT4S',
#   'view_count': '13611',
#   'like_count': '3',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'pkpwNwAPNTw',
#   'title': '这腿也太美了吧！好期待妹妹露脸啊#王者荣耀 #赖神 #美女 #fairy',
#   'description': '这腿也太美了吧！好期待妹妹露脸啊#王者荣耀 #赖神 #美女 #fairy',
#   'published_at': '2022-03-10T09:41:00Z',
#   'channel_title': '灵梦小师妹',
#   'tags': '',
#   'category_id': '42',
#   'duration': 'PT26S',
#   'view_count': '491766',
#   'like_count': '16808',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'gK94jFWhRkk',
#   'title': 'MC中最隐秘的角落，你知道是哪吗？#摸摸鱼 #我的世界 #游戏发行人计划 #doudream创作者计划',
#   'description': 'MC中最隐秘的角落，你知道是哪吗？#摸摸鱼 #我的世界 #游戏发行人计划 #doudream创作者计划',
#   'published_at': '2022-01-09T09:37:00Z',
#   'channel_title': '麦晓花',
#   'tags': '',
#   'category_id': '42',
#   'duration': 'PT49S',
#   'view_count': '35496',
#   'like_count': '2087',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'CpvVYLuGSi0',
#   'title': '得知此消息的我只想一个人静一静！ #教育  #阳光守护  #家庭',
#   'description': '得知此消息的我只想一个人静一静！ #教育  #阳光守护  #家庭',
#   'published_at': '2022-01-13T09:07:00Z',
#   'channel_title': '麦晓花',
#   'tags': '',
#   'category_id': '42',
#   'duration': 'PT56S',
#   'view_count': '79668',
#   'like_count': '5528',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'ZJlQx9Yn53w',
#   'title': '打倒多少拿多少，这样的公司你敢来吗？#办公室游戏 @爆笑办公室',
#   'description': '#shorts',
#   'published_at': '2022-06-03T09:48:00Z',
#   'channel_title': '摸鱼公司',
#   'tags': '',
#   'category_id': '42',
#   'duration': 'PT51S',
#   'view_count': '24728463',
#   'like_count': '712854',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': '[Music] oh oh [Music]'},
#  {'video_id': 'jaHhrsDUbtM',
#   'title': '过去就让它随风而去吧，现在我只想和你一起，拥抱未来 #遇见过去的自己',
#   'description': '过去就让它随风而去吧，现在我只想和你一起，拥抱未来 #遇见过去的自己',
#   'published_at': '2022-04-01T09:52:00Z',
#   'channel_title': '两个橘子',
#   'tags': '',
#   'category_id': '42',
#   'duration': 'PT21S',
#   'view_count': '136718',
#   'like_count': '7041',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'QM0uJ_SZaOc',
#   'title': 'Metamorphosis',
#   'description': 'Ferguson has the garden project torn down, and Doreen blames Franky. Vera grows suspicious of Fletch, who has been acting strangely, and Doreen receives unexpected news.',
#   'published_at': '2017-03-20T04:00:20Z',
#   'channel_title': 'Wentworth',
#   'tags': '',
#   'category_id': '43',
#   'duration': 'PT46M45S',
#   'view_count': 0,
#   'like_count': '1',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'ANyC63ajzcc',
#   'title': 'Rules of Engagement - Fountain of Youth',
#   'description': 'Expecting a rowdy reunion, Jeff (Patrick Warburton) is disappointed when his old college friends talk about their kids and go to bed early.  Russell (David Spade) finds a way to hit on women even when Timmy (Adhir Kajlich) takes him to volunteer at a nursing home.  Adam (Oliver Hudson) films his pet bird doing tricks and aims for YouTube stardom.',
#   'published_at': '2013-03-05T08:03:20Z',
#   'channel_title': 'Rules Of Engagement',
#   'tags': '',
#   'category_id': '43',
#   'duration': 'PT21M31S',
#   'view_count': 0,
#   'like_count': '9',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'yZHw5Qf5Mp8',
#   'title': 'Dog Days of Bummer',
#   'description': 'Murr, Joe, Sal and Q get creative with their French fries at the mall food court and compete to see whose ridiculous invention will win over a focus group. Then, the guys head to the Jersey Shore to serve up some embarrassment at a beachside burger joint.',
#   'published_at': '2013-11-04T08:00:01Z',
#   'channel_title': 'Impractical Jokers',
#   'tags': 'Dog, Days, of, Bummer',
#   'category_id': '43',
#   'duration': 'PT20M18S',
#   'view_count': 0,
#   'like_count': '67',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'fF0PJctMp1Y',
#   'title': 'Episode 3',
#   'description': 'Charlotte suspects her boyfriend is sleeping with her sister. Brooke fears her relationship is near the end.',
#   'published_at': '2024-11-29T05:00:13Z',
#   'channel_title': 'YouTube Movies',
#   'tags': '',
#   'category_id': '43',
#   'duration': 'PT43M29S',
#   'view_count': 0,
#   'like_count': '11',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'ZvmtsdhZo2U',
#   'title': 'Hard Bargain',
#   'description': 'Michael and his crew help a man whose fiancée is kidnapped from the house he is looking after and Michael considers taking a meeting with someone who may be able to revoke his burn notice.',
#   'published_at': '2013-04-02T00:40:20Z',
#   'channel_title': 'Burn Notice',
#   'tags': '',
#   'category_id': '43',
#   'duration': 'PT42M1S',
#   'view_count': 0,
#   'like_count': '38',
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'RTDfhNxv6uU',
#   'title': 'Elysium - Trailer',
#   'description': "In the year 2159, two classes of people exist: the very wealthy, who live on a pristine man-made space station called Elysium, and the rest, who live on an overpopulated, ruined Earth. Secretary Delacourt (Jodie Foster) will stop at nothing to preserve the luxurious lifestyle of the citizens of Elysium -- but that doesn't stop the people of Earth from trying to get in by any means they can. Max (Matt Damon) agrees to take on a life-threatening mission, one that could bring equality to these polarized worlds.",
#   'published_at': '2013-10-03T18:38:36Z',
#   'channel_title': 'Sony Pictures Home Entertainment',
#   'tags': 'Film, Film & Animation, Sonypicture_longform, Matt Damon, Jodie Foster, Sharlto Copley, Alice Braga, Diego Luna, Wagner Moura, William Fichtner, Brandon Auret, Josh Blacker, Emma Tremblay, Jose Pablo Cantillo, Maxwell Perry Cotton, Faran Tahir, Science Fiction, Drama, Action & Adventure, Neill Blomkamp, Bill Block, Simon Kinberg, Elysium',
#   'category_id': '44',
#   'duration': 'PT2M6S',
#   'view_count': '199706',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': 'en',
#   'transcript': ''},
#  {'video_id': 'e-s_t1nExk8',
#   'title': 'The Hangover Part III - Trailer',
#   'description': "It's been two years. Phil, Stu and Doug are happily living uneventful lives at home. Tattoos have been lasered off, files purged. The guys have nearly recovered from their roofie'd nights of Las Vegas and being kidnapped, shot at, and chased by mobsters in Bangkok. The only member of the Wolfpack who's not content is Alan. Still lacking a sense of purpose, he has ditched his meds and given in to his natural impulses in a big way-until a personal crisis forces him to finally seek the help of his three best friends. With no bachelor party and no wedding, what could possibly go wrong? But when the Wolfpack hits the road, all bets are off. It is the epic conclusion to an odyssey of mayhem and bad decisions, in which the guys must finish what they started by going back to where it all began: Las Vegas. One way or another...it all ends here. #Trailer #WB",
#   'published_at': '2013-09-11T11:56:41Z',
#   'channel_title': 'Warner Movies On Demand',
#   'tags': 'The, Hangover, Part, III, Trailer',
#   'category_id': '44',
#   'duration': 'PT2M19S',
#   'view_count': '222332',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'Eq-7ry44r5I',
#   'title': 'Kong: Skull Island - Trailer',
#   'description': 'When a scientific expedition to an uncharted island awakens titanic forces of nature, a mission of discovery becomes an explosive war between monster and man. Tom Hiddleston, Samuel L. Jackson, Brie Larson, John Goodman and John C. Reilly star in a thrilling and original adventure that reveals the untold story of how Kong became King.',
#   'published_at': '2017-03-10T05:00:04Z',
#   'channel_title': 'Warner Movies On Demand',
#   'tags': 'Kong: Skull Island, WB',
#   'category_id': '44',
#   'duration': 'PT2M25S',
#   'view_count': '227305',
#   'like_count': '183',
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': 'Ecn8dvDK7LQ',
#   'title': 'Lemonade Mouth - Trailer',
#   'description': 'Be heard. Be strong. Be proud. Its time to turn up the music and have some fun with an all-new Disney Original Movie, starring Bridgit Mendler and Adam Hicks and introducing ten awesome new songs! When five ragtag freshman first meet in detention, it seems they have nothing in common. But, through music, they form an unbreakable bond and discover they have the makings of the greatest high school garage band in history! In the face of incredible odds, Olivia, Stella, Wen, Mohini and Charlie find they can make a real difference when they learn to lean on each other and let go of everything holding back their dreams. Life is just a roller coaster take the ride!',
#   'published_at': '2012-07-11T16:50:42Z',
#   'channel_title': 'DisneyMoviesOnDemand',
#   'tags': 'Lemonade Mouth, Bridgit Mendler, Adam Hicks, Hayley Kiyoko, Disney',
#   'category_id': '44',
#   'duration': 'PT1M33S',
#   'view_count': '1335345',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''},
#  {'video_id': '71rDQ7z4eFg',
#   'title': 'Catch Me If You Can - Trailer',
#   'description': "Frank didn't go to flight school...Frank didn't go to medical school...Frank didn't go to law school...because Frank's still in high school!\n\nInspired by the true story of a brilliant young master of deception and the FBI agent hot on his trail. Directed by Steven Spielberg and starring Leonardo DiCaprio and Tom Hanks. Frank W. Abagnale, Jr. successfully passes himself off as a pilot, a lawyer and a doctor -- all before his 21st birthday!",
#   'published_at': '2013-04-30T02:16:28Z',
#   'channel_title': 'Paramount Movies',
#   'tags': 'Movies, Paramount',
#   'category_id': '44',
#   'duration': 'PT2M35S',
#   'view_count': '3379659',
#   'like_count': 0,
#   'dislike_count': 0,
#   'default_audio_language': '',
#   'transcript': ''}]

# %%
# Convert data to a DataFrame
df = pd.DataFrame(all_data)

# Define the output file path
output_file = "../data/raw/inference_sample_1.xlsx"

# Create the directory if it does not exist
output_dir = os.path.dirname(output_file)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save the collected data to an Excel file
df.to_excel(output_file, index=False, engine='openpyxl')
print(f"Data saved to {output_file}")
# Out:
# Data saved to ../data/raw/inference_sample_1.xlsx

# %% [markdown]
# ## add a column "kids safe"

# %%
# Step: Read the Excel file into a DataFrame
df_output = pd.read_excel(output_file, engine='openpyxl')

# Step: Add a new column 'kids_safe' with value 1 for all rows
df_output['kids_safe'] = 1

# Print the DataFrame to confirm changes
print(df_output.head())

# Optionally, save the updated DataFrame back to the file
df_output.to_excel(output_file, index=False, engine='openpyxl')
print(f"Updated DataFrame with 'kids_safe' column saved to {output_file}")
# Out:
#       video_id                                              title  \
# 0  -aqYc5WPd-s  Dalek appeared to help the Allies in World War...
# 1  IJbbpAhjboI  🔴 LIVE: Tom and Jerry | 1 Hour Compilation | T...
# 2  InFOaemJcdU  Lechia Gdańsk - Pogoń Szczecin 1:1 | SKRÓT | E...
# 3  Kq10UVgHeHQ        A LESSON OF MAGIC 🪄✨ | #anime #animemoments
# 4  XviHNdfuB9Y  🎥 THREE BILLBOARDS OUTSIDE EBBONG, MISSOURI (2...
#
#                                          description          published_at  \
# 0                                                NaN  2024-12-09T03:43:41Z
# 1  🚩 Watch more Tom and Jerry - https://goo.gl/RU...  2024-07-10T08:28:07Z
# 2  Lechia Gdańsk 1:1 Pogoń Szczecin\n1:0 - Adam B...  2016-07-23T08:17:07Z
# 3                                                NaN  2024-12-07T23:45:00Z
# 4  A mother personally challenges the local autho...  2018-02-19T14:00:02Z
#
#           channel_title                                               tags  \
# 0         Brought Kooky                                                NaN
# 1          Boomerang UK  Boomerang TV, Boomerang UK, Cartoon, Cartoon f...
# 2  Ekstraklasa Archiwum  ekstraklasa, piłka nożna, soccer, football, sk...
# 3                Misuaa                                                NaN
# 4          TRAILER CITY  trailer, full movie trailer, new trailer, trai...
#
#    category_id duration  view_count  like_count  dislike_count  \
# 0            1    PT59S       81648        6257              0
# 1            1      P0D    11645702       27847              0
# 2            1  PT2M11S        1557          13              0
# 3            1    PT39S      570696       37035              0
# 4            1  PT1M29S       82428         224              0
#
#   default_audio_language                                         transcript  \
# 0                  en-US  our new secret weapon I am your soldier what I...
# 1                  en-GB                                                NaN
# 2                    NaN                                                NaN
# 3                  en-US  Opti RS that's all there is to it now you give...
# 4                     en  anyway trying to make me believe in reincarnat...
#
#    kids_safe
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# Updated DataFrame with 'kids_safe' column saved to ../data/raw/video_metadata_by_category_kids.xlsx

# %% [markdown]
# ## Combine metadata excel sheets.

# %%
import pandas as pd

# Load the Excel sheets into dataframes
df1 = pd.read_excel("/Users/shusritavenugopal/Documents/MSIS/FALL2024/InformationStorageAndRetrieval/video_classification_project/data/raw/video_metadata_by_category.xlsx")
df2 = pd.read_excel("/Users/shusritavenugopal/Documents/MSIS/FALL2024/InformationStorageAndRetrieval/video_classification_project/data/raw/video_metadata.xlsx")

# Verify dataframes are loaded correctly
print("DataFrame 1 (Sheet 1):")
df1.head()
# Out:
# DataFrame 1 (Sheet 1):
#       video_id                                              title  \
# 0  crxHAtFqU4o   When a Pilot Sank a Submarine to Avenge a Friend
# 1  qHecSpzXs3s  Fiona gave her best time to her younger siblin...
# 2  XviHNdfuB9Y  🎥 THREE BILLBOARDS OUTSIDE EBBONG, MISSOURI (2...
# 3  ObGVA1WOqyE  🎥 THE PRESTIGE (2006) | Full Movie Trailer in ...
# 4  lTjkFcVlypQ  🔴 LIVE! Phineas and Ferb Season 1 Full Episode...
#
#                                          description          published_at  \
# 0  Prepare to embark on a voyage like no other as...  2024-11-28T23:15:08Z
# 1                                                NaN  2024-11-28T15:48:00Z
# 2  A mother personally challenges the local autho...  2018-02-19T14:00:02Z
# 3  After a tragic accident two stage magicians en...  2018-02-01T14:00:03Z
# 4  Ferb! I know what we're gonna do today! Watch ...  2024-10-18T18:01:23Z
#
#      channel_title                                               tags  \
# 0          Yarnhub                                                NaN
# 1   Brianna Movies                                                NaN
# 2     TRAILER CITY  trailer, full movie trailer, new trailer, trai...
# 3  MOVIE PREDICTOR  trailer, full movie trailer, official trailer,...
# 4        Disney XD  phineas and ferb, phineas and ferb full episod...
#
#    category_id  duration  view_count  like_count  dislike_count  \
# 0            1  PT12M17S      505645       16878              0
# 1            1      PT1M      369560       27635              0
# 2            1   PT1M29S       82425         224              0
# 3            1   PT2M48S      444240        3246              0
# 4            1       P0D     2480550       10100              0
#
#   default_audio_language                                         transcript
# 0                     en  It's December 7 , 1941. In the Pacific, Lieute...
# 1                  en-US  Miss Gallagher you want to tell me why your fa...
# 2                     en  anyway trying to make me believe in reincarnat...
# 3                     en  surely come on no I can't hey how do you do it...
# 4                     en                                                NaN

# %%
df1.columns
# Out:
# Index(['video_id', 'title', 'description', 'published_at', 'channel_title',
#        'tags', 'category_id', 'duration', 'view_count', 'like_count',
#        'dislike_count', 'default_audio_language', 'transcript'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Video ID', 'Title', 'Description', 'Published At', 'Channel Title',
#        'Tags', 'Category ID', 'Category Label', 'Default Audio Language',
#        'Transcript'],
#       dtype='object')

# %%
# Standardize column names in dataset2 to match dataset1 for merging
df2 = df2.rename(columns={
    'Video ID': 'video_id',
    'Title': 'title',
    'Description': 'description',
    'Published At': 'published_at',
    'Channel Title': 'channel_title',
    'Tags': 'tags',
    'Category ID': 'category_id',
    'Category Label': 'Category Label',
    'Default Audio Language': 'default_audio_language',
    'Transcript': 'transcript'
})

# Add missing columns in df2
df2['duration'] = None
df2['view_count'] = None
df2['like_count'] = None
df2['dislike_count'] = None

# Combine the datasets
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save the combined dataset to an Excel file
output_file = 'combined_dataset.xlsx'
combined_df.to_excel(output_file, index=False, engine='openpyxl')

print(f"Combined dataset saved to {output_file}")
# Out:
# Combined dataset saved to combined_dataset.xlsx

# %%
# File path of the second Excel file
output_file = "../data/raw/video_metadata_by_category_kids.xlsx"
second_file = "../data/raw/combined_dataset.xlsx"

# Step: Read both Excel files into DataFrames
df_output = pd.read_excel(output_file, engine='openpyxl')  # Our output file
df_second = pd.read_excel(second_file, engine='openpyxl')  # Existing file

# Step: Ensure both DataFrames have the same structure
# Add a 'kids_safe' column to the second DataFrame, leaving it empty
df_second['kids_safe'] = None

# Step: Merge the two DataFrames
merged_df = pd.concat([df_output, df_second], ignore_index=True)

# Print the first few rows of the merged DataFrame to verify
print(merged_df.head())

# Step: Save the merged DataFrame back to a new Excel file
merged_file = "../data/raw/master_dataset.xlsx"
merged_df.to_excel(merged_file, index=False, engine='openpyxl')
print(f"Merged data saved to {merged_file}")
# Out:
#       video_id                                              title  \
# 0  -aqYc5WPd-s  Dalek appeared to help the Allies in World War...
# 1  IJbbpAhjboI  🔴 LIVE: Tom and Jerry | 1 Hour Compilation | T...
# 2  InFOaemJcdU  Lechia Gdańsk - Pogoń Szczecin 1:1 | SKRÓT | E...
# 3  Kq10UVgHeHQ        A LESSON OF MAGIC 🪄✨ | #anime #animemoments
# 4  XviHNdfuB9Y  🎥 THREE BILLBOARDS OUTSIDE EBBONG, MISSOURI (2...
#
#                                          description          published_at  \
# 0                                                NaN  2024-12-09T03:43:41Z
# 1  🚩 Watch more Tom and Jerry - https://goo.gl/RU...  2024-07-10T08:28:07Z
# 2  Lechia Gdańsk 1:1 Pogoń Szczecin\n1:0 - Adam B...  2016-07-23T08:17:07Z
# 3                                                NaN  2024-12-07T23:45:00Z
# 4  A mother personally challenges the local autho...  2018-02-19T14:00:02Z
#
#           channel_title                                               tags  \
# 0         Brought Kooky                                                NaN
# 1          Boomerang UK  Boomerang TV, Boomerang UK, Cartoon, Cartoon f...
# 2  Ekstraklasa Archiwum  ekstraklasa, piłka nożna, soccer, football, sk...
# 3                Misuaa                                                NaN
# 4          TRAILER CITY  trailer, full movie trailer, new trailer, trai...
#
#    category_id duration  view_count  like_count  dislike_count  \
# 0            1    PT59S     81648.0      6257.0            0.0
# 1            1      P0D  11645702.0     27847.0            0.0
# 2            1  PT2M11S      1557.0        13.0            0.0
# 3            1    PT39S    570696.0     37035.0            0.0
# 4            1  PT1M29S     82428.0       224.0            0.0
#
#   default_audio_language                                         transcript  \
# 0                  en-US  our new secret weapon I am your soldier what I...
# 1                  en-GB                                                NaN
# 2                    NaN                                                NaN
# 3                  en-US  Opti RS that's all there is to it now you give...
# 4                     en  anyway trying to make me believe in reincarnat...
#
#   kids_safe Category Label
# 0         1            NaN
# 1         1            NaN
# 2         1            NaN
# 3         1            NaN
# 4         1            NaN
# Merged data saved to ../data/raw/master_dataset.xlsx
